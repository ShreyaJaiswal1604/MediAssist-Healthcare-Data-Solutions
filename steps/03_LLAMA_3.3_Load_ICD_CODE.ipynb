# %%
! pip install snowflake-connector-python
# Out:
# Python(69882) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Requirement already satisfied: snowflake-connector-python in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (3.11.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (1.17.1)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (42.0.8)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (24.2.1)
# Requirement already satisfied: pyjwt<3.0.0 in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (2.9.0)
# Requirement already satisfied: pytz in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (2024.2)
# Requirement already satisfied: requests<3.0.0 in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (2.32.3)
# Requirement already satisfied: packaging in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (24.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (2024.8.30)
# Requirement already satisfied: typing-extensions<5,>=4.3 in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (4.12.2)
# Requirement already satisfied: filelock<4,>=3.5 in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (3.16.1)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (4.3.6)
# Requirement already satisfied: tomlkit in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (0.13.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.21.1 in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from snowflake-connector-python) (1.26.20)
# Requirement already satisfied: pycparser in /Users/shreyajaiswal/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.22)

# %% [markdown]
# ---
#
# IMPORTS
#
# ---

# %%
import snowflake.connector
import pandas as pd
import re
from datetime import datetime
from huggingface_hub import InferenceClient

# %% [markdown]
# ---
#
# SNOWFLAKE
#
# ---

# %%
# Snowflake Configuration
SNOWFLAKE_CONFIG = {
    "user": "DOLPHIN",
    "password": "Maapaa@1603",
    "account": "URB63596",
    "warehouse": "ANIMAL_TASK_WH",
    "database": "mimic_iv_medi_assist",
    "schema": "PROD_MIMIC",
}

# %%
# SQL Queries
SELECT_QUERY = f"""
SELECT DIS_RECORD_ID, DIS_NOTE_TEXT
FROM MIMIC_IV_MEDI_ASSIST.PROD_MIMIC.DIM_DISCHARGE
WHERE DIS_NOTE_TEXT IS NOT NULL
"""

UNPROCESSED_RECORDS_QUERY = f"""
SELECT d.DIS_RECORD_ID, d.DIS_NOTE_TEXT
FROM MIMIC_IV_MEDI_ASSIST.PROD_MIMIC.DIM_DISCHARGE d
WHERE d.DIS_NOTE_TEXT IS NOT NULL
  AND d.DIS_RECORD_ID NOT IN (
      SELECT DISTINCT l.DIS_RECORD_ID
      FROM MIMIC_IV_MEDI_ASSIST.PROD_MIMIC.DIM_MEDICAL_CODES_LLM l
  )
"""


INSERT_MEDICAL_CODES_QUERY = f"""
INSERT INTO MIMIC_IV_MEDI_ASSIST.PROD_MIMIC.DIM_MEDICAL_CODES_LLM
(DIS_RECORD_ID, DMC_ICD_CODE, CREATED_AT)
VALUES (%s, %s, %s)
"""

UPDATE_SUMMARY_QUERY = f"""
UPDATE MIMIC_IV_MEDI_ASSIST.PROD_MIMIC.DIM_DISCHARGE
SET DIS_NOTE_SUMMARY = %s
WHERE DIS_RECORD_ID = %s
"""

# %%
# Helper: Connect to Snowflake
def connect_to_snowflake():
    """Establish a connection to Snowflake."""
    print("Connecting to Snowflake...")
    return snowflake.connector.connect(**SNOWFLAKE_CONFIG)

# %% [markdown]
# ---
# LLM CODE GENERATION
#
# ---

# %%
# Helper: Call LLM for ICD-10 Code Generation
def call_llm_for_icd(clinical_note):
    """
    Call an LLM to generate ICD-10 codes from a clinical note.

    Args:
        clinical_note (str): Clinical text to analyze.

    Returns:
        list: A list of ICD-10 codes.
    """
    print("Calling LLM for ICD-10 code generation...")

    # Initialize the LLM client
    client = InferenceClient(api_key="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")

    # Define the prompt for ICD-10 code generation
    prompt_medical_code = f"""
        You are an advanced clinical language model specializing in analyzing patient clinical notes to generate accurate ICD-10 codes.
        Carefully analyze the following clinical note and provide the 5 most relevant ICD-10 codes as a Python list of strings. Do not include explanations, additional text, or any code in the output.

        Clinical Note:
        {clinical_note}

        Return the output in this exact format:

        ["ICD10_CODE_1", "ICD10_CODE_2", "ICD10_CODE_3", ..., "ICD10_CODE_5"]
    """

    # LLM API Call
    messages = [{"role": "user", "content": prompt_medical_code}]
    completion = client.chat.completions.create(
        model="meta-llama/Llama-3.3-70B-Instruct",
        messages=messages,
        max_tokens=500
    )

    # Parse the response
    icd_codes = completion.choices[0].message["content"]

    try:
        print("Parsing ICD-10 codes...")
        return eval(icd_codes)  # Convert response to a Python list
    except Exception as e:
        print(f"Error parsing ICD-10 codes: {e}")
        return []

# %%
# Main workflow
def process_discharge_notes():
    """Read clinical notes from Snowflake and generate ICD-10 codes."""
    try:
        # Connect to Snowflake
        conn = connect_to_snowflake()
        cursor = conn.cursor()

        print("Fetching unprocessed discharge notes...")
        # Execute the query to fetch clinical notes
        cursor.execute(UNPROCESSED_RECORDS_QUERY)
        records = cursor.fetchall()

        print(f"Fetched {len(records)} records.")

        for record_id, clinical_note in records:
            print(f"Processing Record ID: {record_id}")

            # Generate ICD-10 codes for each clinical note
            icd_codes = call_llm_for_icd(clinical_note)

            # Print the generated ICD-10 codes
            print(f"Record ID: {record_id}")
            print(f"ICD-10 Codes: {icd_codes}\n")

        # Close the connection
        cursor.close()
        conn.close()
        print("Processing completed and connection closed.")

    except Exception as e:
        print(f"Error processing discharge notes: {e}")

# %%
# Helper: Clean ICD-10 Codes
def clean_icd_codes(icd_codes):
    """
    Clean ICD-10 codes by removing periods and trimming whitespace.

    Args:
        icd_codes (list): List of raw ICD-10 codes.

    Returns:
        list: Cleaned ICD-10 codes.
    """
    print("Cleaning ICD-10 codes...")
    return [code.replace(".", "").strip() for code in icd_codes]

# %%
# Main Workflow
def process_discharge_notes():
    """Process discharge notes to generate and insert ICD-10 codes into Snowflake."""
    try:
        # Connect to Snowflake
        conn = connect_to_snowflake()
        cursor = conn.cursor()

        print("Fetching unprocessed discharge notes...")
        cursor.execute(UNPROCESSED_RECORDS_QUERY)
        records = cursor.fetchall()

        print(f"Fetched {len(records)} records.")

        for dis_record_id, clinical_note in records:
            print(f"Processing Record ID: {dis_record_id}")

            # Generate ICD-10 codes
            raw_icd_codes = call_llm_for_icd(clinical_note)
            cleaned_icd_codes = clean_icd_codes(raw_icd_codes)

            print(f"Raw ICD-10 Codes: {raw_icd_codes}")
            print(f"Cleaned ICD-10 Codes: {cleaned_icd_codes}")

            # Insert cleaned ICD-10 codes into Snowflake
            created_at = datetime.utcnow().isoformat()
            icd_records = [(dis_record_id, code, created_at) for code in cleaned_icd_codes]

            try:
                cursor.executemany(INSERT_MEDICAL_CODES_QUERY, icd_records)
                conn.commit()
                print(f"Inserted ICD-10 codes for Discharge Record ID: {dis_record_id}")
            except Exception as e:
                print(f"Error inserting ICD-10 codes for Discharge Record ID {dis_record_id}: {e}")

        # Close connections
        cursor.close()
        conn.close()
        print("Processing completed. Connection closed.")

    except Exception as e:
        print(f"Error processing discharge notes: {e}")

# %%
# Run the Workflow
if __name__ == "__main__":
    print("Starting discharge note processing...")
    process_discharge_notes()
    print("Discharge note processing finished.")
# Out:
# Starting discharge note processing...
# Connecting to Snowflake...
# Fetching unprocessed discharge notes...
# Fetched 248265 records.
# Processing Record ID: 27053
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['Q44.6', 'N18.9', 'E87.1', 'K71.0', 'R10.9']
# Cleaned ICD-10 Codes: ['Q446', 'N189', 'E871', 'K710', 'R109']
# Inserted ICD-10 codes for Discharge Record ID: 27053
# Processing Record ID: 140093
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I63.50', 'I61.5', 'G31.83', 'I21.4', 'C67.9']
# Cleaned ICD-10 Codes: ['I6350', 'I615', 'G3183', 'I214', 'C679']
# Inserted ICD-10 codes for Discharge Record ID: 140093
# Processing Record ID: 316324
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['F10.129', 'K70.0', 'E86.0', 'G62.1', 'R11.2']
# Cleaned ICD-10 Codes: ['F10129', 'K700', 'E860', 'G621', 'R112']
# Inserted ICD-10 codes for Discharge Record ID: 316324
# Processing Record ID: 146675
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K92.2', 'I85.919', 'N18.6', 'I48.0', 'E11.9']
# Cleaned ICD-10 Codes: ['K922', 'I85919', 'N186', 'I480', 'E119']
# Inserted ICD-10 codes for Discharge Record ID: 146675
# Processing Record ID: 307578
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['C22.0', 'I82.509', 'E11.9', 'K76.1', 'Z95.828']
# Cleaned ICD-10 Codes: ['C220', 'I82509', 'E119', 'K761', 'Z95828']
# Inserted ICD-10 codes for Discharge Record ID: 307578
# Processing Record ID: 184098
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I50.21', 'I25.10', 'I42.0', 'G47.33', 'E78.5']
# Cleaned ICD-10 Codes: ['I5021', 'I2510', 'I420', 'G4733', 'E785']
# Inserted ICD-10 codes for Discharge Record ID: 184098
# Processing Record ID: 177871
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['M96.1', 'Z87.39', 'Z95.899', 'E87.4', 'I10']
# Cleaned ICD-10 Codes: ['M961', 'Z8739', 'Z95899', 'E874', 'I10']
# Inserted ICD-10 codes for Discharge Record ID: 177871
# Processing Record ID: 46296
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K27.0', 'K26.9', 'R11.0', 'R04.2', 'K21.9']
# Cleaned ICD-10 Codes: ['K270', 'K269', 'R110', 'R042', 'K219']
# Inserted ICD-10 codes for Discharge Record ID: 46296
# Processing Record ID: 153311
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['C56.9', 'N83.2', 'R10.2', 'E87.5', 'T81.1']
# Cleaned ICD-10 Codes: ['C569', 'N832', 'R102', 'E875', 'T811']
# Inserted ICD-10 codes for Discharge Record ID: 153311
# Processing Record ID: 38431
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K52.9', 'R10.9', 'A09', 'R19.7', 'K58.9']
# Cleaned ICD-10 Codes: ['K529', 'R109', 'A09', 'R197', 'K589']
# Inserted ICD-10 codes for Discharge Record ID: 38431
# Processing Record ID: 318364
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I62.00', 'G93.1', 'S06.4X0A', 'I21.4', 'E11.9']
# Cleaned ICD-10 Codes: ['I6200', 'G931', 'S064X0A', 'I214', 'E119']
# Inserted ICD-10 codes for Discharge Record ID: 318364
# Processing Record ID: 81933
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['S91.832A', 'E11.9', 'I10', 'K21.9', 'Z87.39']
# Cleaned ICD-10 Codes: ['S91832A', 'E119', 'I10', 'K219', 'Z8739']
# Inserted ICD-10 codes for Discharge Record ID: 81933
# Processing Record ID: 320263
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['E11.51', 'N20.9', 'I50.9', 'R41.82', 'N30.0']
# Cleaned ICD-10 Codes: ['E1151', 'N209', 'I509', 'R4182', 'N300']
# Inserted ICD-10 codes for Discharge Record ID: 320263
# Processing Record ID: 140712
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I70.263', 'E11.51', 'I50.423', 'Z87.39', 'I74.50']
# Cleaned ICD-10 Codes: ['I70263', 'E1151', 'I50423', 'Z8739', 'I7450']
# Inserted ICD-10 codes for Discharge Record ID: 140712
# Processing Record ID: 55657
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I50.21', 'I10', 'E78.5', 'J44.9', 'F41.9']
# Cleaned ICD-10 Codes: ['I5021', 'I10', 'E785', 'J449', 'F419']
# Inserted ICD-10 codes for Discharge Record ID: 55657
# Processing Record ID: 163783
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['R56.9', 'G40.909', 'I50.421', 'F31.81', 'T84.592A']
# Cleaned ICD-10 Codes: ['R569', 'G40909', 'I50421', 'F3181', 'T84592A']
# Inserted ICD-10 codes for Discharge Record ID: 163783
# Processing Record ID: 35871
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I67.1', 'S06.9', 'I72.8', 'G44.9', 'Z95.828']
# Cleaned ICD-10 Codes: ['I671', 'S069', 'I728', 'G449', 'Z95828']
# Inserted ICD-10 codes for Discharge Record ID: 35871
# Processing Record ID: 317002
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K26.9', 'E43.9', 'K59.1', 'R10.9', 'Z87.39']
# Cleaned ICD-10 Codes: ['K269', 'E439', 'K591', 'R109', 'Z8739']
# Inserted ICD-10 codes for Discharge Record ID: 317002
# Processing Record ID: 68089
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['R29.6', 'G30.9', 'F03.90', 'E03.9', 'I10']
# Cleaned ICD-10 Codes: ['R296', 'G309', 'F0390', 'E039', 'I10']
# Inserted ICD-10 codes for Discharge Record ID: 68089
# Processing Record ID: 197398
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K76.1', 'E11.9', 'N18.3', 'D64.9', 'B18.1']
# Cleaned ICD-10 Codes: ['K761', 'E119', 'N183', 'D649', 'B181']
# Inserted ICD-10 codes for Discharge Record ID: 197398
# Processing Record ID: 251075
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['N95', 'D25.0', 'E11.9', 'Z85.3', 'Z90.72']
# Cleaned ICD-10 Codes: ['N95', 'D250', 'E119', 'Z853', 'Z9072']
# Inserted ICD-10 codes for Discharge Record ID: 251075
# Processing Record ID: 154526
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I65.2', 'Z95.828', 'I25.10', 'I10', 'Z87.39']
# Cleaned ICD-10 Codes: ['I652', 'Z95828', 'I2510', 'I10', 'Z8739']
# Inserted ICD-10 codes for Discharge Record ID: 154526
# Processing Record ID: 231379
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K91.89', 'E87.6', 'M79.1', 'F02.80', 'E21.0']
# Cleaned ICD-10 Codes: ['K9189', 'E876', 'M791', 'F0280', 'E210']
# Inserted ICD-10 codes for Discharge Record ID: 231379
# Processing Record ID: 258980
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['O11.0', 'O10.0', 'F31.9', 'Z87.39', 'R51']
# Cleaned ICD-10 Codes: ['O110', 'O100', 'F319', 'Z8739', 'R51']
# Inserted ICD-10 codes for Discharge Record ID: 258980
# Processing Record ID: 281489
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['R41.3', 'E87.1', 'I50.4', 'F03.90', 'N39.0']
# Cleaned ICD-10 Codes: ['R413', 'E871', 'I504', 'F0390', 'N390']
# Inserted ICD-10 codes for Discharge Record ID: 281489
# Processing Record ID: 208250
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['C50.919', 'Z85.46', 'T81.1', 'E11.9', 'Z87.39']
# Cleaned ICD-10 Codes: ['C50919', 'Z8546', 'T811', 'E119', 'Z8739']
# Inserted ICD-10 codes for Discharge Record ID: 208250
# Processing Record ID: 50540
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['S72.141', 'Z87.31', 'I10', 'M80.09', 'M16.9']
# Cleaned ICD-10 Codes: ['S72141', 'Z8731', 'I10', 'M8009', 'M169']
# Inserted ICD-10 codes for Discharge Record ID: 50540
# Processing Record ID: 2058
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K57.32', 'B18.9', 'R10.9', 'Z85.812', 'Z87.39']
# Cleaned ICD-10 Codes: ['K5732', 'B189', 'R109', 'Z85812', 'Z8739']
# Inserted ICD-10 codes for Discharge Record ID: 2058
# Processing Record ID: 257568
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['R10.9', 'N83.019', 'C85.902', 'K21.9', 'R18.0']
# Cleaned ICD-10 Codes: ['R109', 'N83019', 'C85902', 'K219', 'R180']
# Inserted ICD-10 codes for Discharge Record ID: 257568
# Processing Record ID: 250697
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['G44.009', 'H46.009', 'M79.1', 'L20.8', 'R51.0']
# Cleaned ICD-10 Codes: ['G44009', 'H46009', 'M791', 'L208', 'R510']
# Inserted ICD-10 codes for Discharge Record ID: 250697
# Processing Record ID: 81017
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I10', 'E86', 'E87.1', 'R55', 'E87.6']
# Cleaned ICD-10 Codes: ['I10', 'E86', 'E871', 'R55', 'E876']
# Inserted ICD-10 codes for Discharge Record ID: 81017
# Processing Record ID: 71567
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['M48.51', 'M80.08', 'S32.0', 'T84.3', 'Z87.39']
# Cleaned ICD-10 Codes: ['M4851', 'M8008', 'S320', 'T843', 'Z8739']
# Inserted ICD-10 codes for Discharge Record ID: 71567
# Processing Record ID: 69326
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['L02.2', 'K13.01', 'R22.1', 'T81.41XA', 'Z43.89']
# Cleaned ICD-10 Codes: ['L022', 'K1301', 'R221', 'T8141XA', 'Z4389']
# Inserted ICD-10 codes for Discharge Record ID: 69326
# Processing Record ID: 15580
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['T85.619', 'N18.6', 'Q61.9', 'I10', 'B18.9']
# Cleaned ICD-10 Codes: ['T85619', 'N186', 'Q619', 'I10', 'B189']
# Inserted ICD-10 codes for Discharge Record ID: 15580
# Processing Record ID: 290720
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K42.1', 'K76.1', 'I85.11', 'B18.2', 'R10.9']
# Cleaned ICD-10 Codes: ['K421', 'K761', 'I8511', 'B182', 'R109']
# Inserted ICD-10 codes for Discharge Record ID: 290720
# Processing Record ID: 307537
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['S27.1', 'T14.1', 'J90', 'S21.1', 'Z87.741']
# Cleaned ICD-10 Codes: ['S271', 'T141', 'J90', 'S211', 'Z87741']
# Inserted ICD-10 codes for Discharge Record ID: 307537
# Processing Record ID: 313739
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['F31.2', 'F60.1', 'I62.9', 'Z91.89', 'R44.3']
# Cleaned ICD-10 Codes: ['F312', 'F601', 'I629', 'Z9189', 'R443']
# Inserted ICD-10 codes for Discharge Record ID: 313739
# Processing Record ID: 182416
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['R42', 'H81.13', 'I67.819', 'E53.9', 'H35.819']
# Cleaned ICD-10 Codes: ['R42', 'H8113', 'I67819', 'E539', 'H35819']
# Inserted ICD-10 codes for Discharge Record ID: 182416
# Processing Record ID: 4536
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['T51.91A', 'F12.229', 'F32.9', 'Z91.89', 'R09.02']
# Cleaned ICD-10 Codes: ['T5191A', 'F12229', 'F329', 'Z9189', 'R0902']
# Inserted ICD-10 codes for Discharge Record ID: 4536
# Processing Record ID: 225265
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K76.1', 'M80.06', 'I85.11', 'D64.9', 'S72.01']
# Cleaned ICD-10 Codes: ['K761', 'M8006', 'I8511', 'D649', 'S7201']
# Inserted ICD-10 codes for Discharge Record ID: 225265
# Processing Record ID: 207213
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['F10.129', 'K70.1', 'D64.9', 'F32.9', 'Z50.2']
# Cleaned ICD-10 Codes: ['F10129', 'K701', 'D649', 'F329', 'Z502']
# Inserted ICD-10 codes for Discharge Record ID: 207213
# Processing Record ID: 284566
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K92.2', 'D50.0', 'C23.9', 'M06.9', 'N18.9']
# Cleaned ICD-10 Codes: ['K922', 'D500', 'C239', 'M069', 'N189']
# Inserted ICD-10 codes for Discharge Record ID: 284566
# Processing Record ID: 197852
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I48.0', 'T82.118A', 'I50.4', 'I10', 'N40.1']
# Cleaned ICD-10 Codes: ['I480', 'T82118A', 'I504', 'I10', 'N401']
# Inserted ICD-10 codes for Discharge Record ID: 197852
# Processing Record ID: 56600
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['C77.1', 'N20.9', 'N13.2', 'E87.5', 'C64.9']
# Cleaned ICD-10 Codes: ['C771', 'N209', 'N132', 'E875', 'C649']
# Inserted ICD-10 codes for Discharge Record ID: 56600
# Processing Record ID: 262859
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['F43.23', 'E11.9', 'N18.6', 'I50.0', 'Z91.89']
# Cleaned ICD-10 Codes: ['F4323', 'E119', 'N186', 'I500', 'Z9189']
# Inserted ICD-10 codes for Discharge Record ID: 262859
# Processing Record ID: 213458
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['L03.116', 'R51.0', 'E87.4', 'I10', 'Z87.39']
# Cleaned ICD-10 Codes: ['L03116', 'R510', 'E874', 'I10', 'Z8739']
# Inserted ICD-10 codes for Discharge Record ID: 213458
# Processing Record ID: 62671
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['E66.01', 'Z98.89', 'T81.1', 'K91.89', 'Z48.2']
# Cleaned ICD-10 Codes: ['E6601', 'Z9889', 'T811', 'K9189', 'Z482']
# Inserted ICD-10 codes for Discharge Record ID: 62671
# Processing Record ID: 86143
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['J18.9', 'J86.0', 'E11.9', 'F32.9', 'K76.0']
# Cleaned ICD-10 Codes: ['J189', 'J860', 'E119', 'F329', 'K760']
# Inserted ICD-10 codes for Discharge Record ID: 86143
# Processing Record ID: 269112
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K56.7', 'K66.0', 'R10.9', 'T81.2', 'E87.4']
# Cleaned ICD-10 Codes: ['K567', 'K660', 'R109', 'T812', 'E874']
# Inserted ICD-10 codes for Discharge Record ID: 269112
# Processing Record ID: 89233
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['J44.9', 'C34.1', 'N18.9', 'R06.00', 'Z95.5']
# Cleaned ICD-10 Codes: ['J449', 'C341', 'N189', 'R0600', 'Z955']
# Inserted ICD-10 codes for Discharge Record ID: 89233
# Processing Record ID: 185742
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['S06.4X0A', 'S06.5X0A', 'M54.5', 'I21.9', 'G31.83']
# Cleaned ICD-10 Codes: ['S064X0A', 'S065X0A', 'M545', 'I219', 'G3183']
# Inserted ICD-10 codes for Discharge Record ID: 185742
# Processing Record ID: 307398
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I80.2', 'L03.115', 'I48.2', 'I82.509', 'E87.4']
# Cleaned ICD-10 Codes: ['I802', 'L03115', 'I482', 'I82509', 'E874']
# Inserted ICD-10 codes for Discharge Record ID: 307398
# Processing Record ID: 266905
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['E27.4', 'I10', 'N18.9', 'M07.3', 'R41.0']
# Cleaned ICD-10 Codes: ['E274', 'I10', 'N189', 'M073', 'R410']
# Inserted ICD-10 codes for Discharge Record ID: 266905
# Processing Record ID: 63944
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['T39.1X4A', 'F12.20', 'F10.20', 'T42.6X4A', 'R07.9']
# Cleaned ICD-10 Codes: ['T391X4A', 'F1220', 'F1020', 'T426X4A', 'R079']
# Inserted ICD-10 codes for Discharge Record ID: 63944
# Processing Record ID: 103250
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['S82.62XA', 'M16.17', 'T84.30XA', 'Z87.39', 'Z91.19']
# Cleaned ICD-10 Codes: ['S8262XA', 'M1617', 'T8430XA', 'Z8739', 'Z9119']
# Inserted ICD-10 codes for Discharge Record ID: 103250
# Processing Record ID: 202640
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I50.41', 'J44.1', 'D64.9', 'N39.0', 'I10']
# Cleaned ICD-10 Codes: ['I5041', 'J441', 'D649', 'N390', 'I10']
# Inserted ICD-10 codes for Discharge Record ID: 202640
# Processing Record ID: 295059
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['C80.0', 'R41.82', 'E11.9', 'C50.919', 'I69.398']
# Cleaned ICD-10 Codes: ['C800', 'R4182', 'E119', 'C50919', 'I69398']
# Inserted ICD-10 codes for Discharge Record ID: 295059
# Processing Record ID: 293439
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['R07.9', 'I25.10', 'I10', 'K64.9', 'Z95.5']
# Cleaned ICD-10 Codes: ['R079', 'I2510', 'I10', 'K649', 'Z955']
# Inserted ICD-10 codes for Discharge Record ID: 293439
# Processing Record ID: 231309
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I21.4', 'I10', 'F32.9', 'L40.9', 'Z95.5']
# Cleaned ICD-10 Codes: ['I214', 'I10', 'F329', 'L409', 'Z955']
# Inserted ICD-10 codes for Discharge Record ID: 231309
# Processing Record ID: 66195
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['N17.9', 'K71.2', 'D69.6', 'R10.9', 'E11.9']
# Cleaned ICD-10 Codes: ['N179', 'K712', 'D696', 'R109', 'E119']
# Inserted ICD-10 codes for Discharge Record ID: 66195
# Processing Record ID: 63433
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I50.01', 'G31.84', 'H53.49', 'M96.81', 'R29.6']
# Cleaned ICD-10 Codes: ['I5001', 'G3184', 'H5349', 'M9681', 'R296']
# Inserted ICD-10 codes for Discharge Record ID: 63433
# Processing Record ID: 59105
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I10', 'N18.4', 'M31.7', 'D69.6', 'E11.9']
# Cleaned ICD-10 Codes: ['I10', 'N184', 'M317', 'D696', 'E119']
# Inserted ICD-10 codes for Discharge Record ID: 59105
# Processing Record ID: 92963
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['T84.612', 'N18.9', 'M84.453', 'I25.10', 'E87.4']
# Cleaned ICD-10 Codes: ['T84612', 'N189', 'M84453', 'I2510', 'E874']
# Inserted ICD-10 codes for Discharge Record ID: 92963
# Processing Record ID: 185248
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['S36.11', 'R10.9', 'F44.9', 'G40.9', 'Z85.39']
# Cleaned ICD-10 Codes: ['S3611', 'R109', 'F449', 'G409', 'Z8539']
# Inserted ICD-10 codes for Discharge Record ID: 185248
# Processing Record ID: 295714
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['C83.31', 'C79.71', 'E87.7', 'R51', 'I95.2']
# Cleaned ICD-10 Codes: ['C8331', 'C7971', 'E877', 'R51', 'I952']
# Inserted ICD-10 codes for Discharge Record ID: 295714
# Processing Record ID: 268385
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I21.4', 'I10', 'N18.4', 'E11.9', 'Z95.5']
# Cleaned ICD-10 Codes: ['I214', 'I10', 'N184', 'E119', 'Z955']
# Inserted ICD-10 codes for Discharge Record ID: 268385
# Processing Record ID: 248984
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K92.0', 'M54.9', 'E11.9', 'F41.9', 'F43.9']
# Cleaned ICD-10 Codes: ['K920', 'M549', 'E119', 'F419', 'F439']
# Inserted ICD-10 codes for Discharge Record ID: 248984
# Processing Record ID: 144833
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['G56.0', 'R42', 'I48.1', 'Z88.8', 'R51']
# Cleaned ICD-10 Codes: ['G560', 'R42', 'I481', 'Z888', 'R51']
# Inserted ICD-10 codes for Discharge Record ID: 144833
# Processing Record ID: 58438
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I63.50', 'G31.83', 'I10', 'N18.9', 'R41.82']
# Cleaned ICD-10 Codes: ['I6350', 'G3183', 'I10', 'N189', 'R4182']
# Inserted ICD-10 codes for Discharge Record ID: 58438
# Processing Record ID: 94353
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K76.1', 'I85.11', 'E87.7', 'F11.2', 'B18.2']
# Cleaned ICD-10 Codes: ['K761', 'I8511', 'E877', 'F112', 'B182']
# Inserted ICD-10 codes for Discharge Record ID: 94353
# Processing Record ID: 289661
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I63.50', 'I65.21', 'I10', 'E78.5', 'G45.9']
# Cleaned ICD-10 Codes: ['I6350', 'I6521', 'I10', 'E785', 'G459']
# Inserted ICD-10 codes for Discharge Record ID: 289661
# Processing Record ID: 124272
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['M47.812', 'G99.2', 'M50.02', 'Z87.39', 'Z48.89']
# Cleaned ICD-10 Codes: ['M47812', 'G992', 'M5002', 'Z8739', 'Z4889']
# Inserted ICD-10 codes for Discharge Record ID: 124272
# Processing Record ID: 215405
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['J18.9', 'N18.6', 'E10.9', 'I48.0', 'J44.9']
# Cleaned ICD-10 Codes: ['J189', 'N186', 'E109', 'I480', 'J449']
# Inserted ICD-10 codes for Discharge Record ID: 215405
# Processing Record ID: 213570
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['BPH', 'R32', 'T85.618', 'N40.1', 'Z48.2']
# Cleaned ICD-10 Codes: ['BPH', 'R32', 'T85618', 'N401', 'Z482']
# Inserted ICD-10 codes for Discharge Record ID: 213570
# Processing Record ID: 317850
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['M16.1', 'Z87.39', 'Z95.2', 'E87.8', 'F32.9']
# Cleaned ICD-10 Codes: ['M161', 'Z8739', 'Z952', 'E878', 'F329']
# Inserted ICD-10 codes for Discharge Record ID: 317850
# Processing Record ID: 172835
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K57.32', 'F10.2', 'R10.9', 'R11.2', 'Z87.39']
# Cleaned ICD-10 Codes: ['K5732', 'F102', 'R109', 'R112', 'Z8739']
# Inserted ICD-10 codes for Discharge Record ID: 172835
# Processing Record ID: 316985
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['C92.0', 'D64.9', 'E11.9', 'I48.0', 'R26.0']
# Cleaned ICD-10 Codes: ['C920', 'D649', 'E119', 'I480', 'R260']
# Inserted ICD-10 codes for Discharge Record ID: 316985
# Processing Record ID: 145342
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K76.1', 'I85.01', 'K72.1', 'E87.6', 'F10.2']
# Cleaned ICD-10 Codes: ['K761', 'I8501', 'K721', 'E876', 'F102']
# Inserted ICD-10 codes for Discharge Record ID: 145342
# Processing Record ID: 267285
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['J45.909', 'T88.6', 'Z88.8', 'J30.1', 'Z87.19']
# Cleaned ICD-10 Codes: ['J45909', 'T886', 'Z888', 'J301', 'Z8719']
# Inserted ICD-10 codes for Discharge Record ID: 267285
# Processing Record ID: 59294
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K43.9', 'D51.0', 'E84.130', 'C81.99', 'R10.9']
# Cleaned ICD-10 Codes: ['K439', 'D510', 'E84130', 'C8199', 'R109']
# Inserted ICD-10 codes for Discharge Record ID: 59294
# Processing Record ID: 86641
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['S27.311A', 'S32.009A', 'S42.301A', 'T14.91XA', 'M96.1']
# Cleaned ICD-10 Codes: ['S27311A', 'S32009A', 'S42301A', 'T1491XA', 'M961']
# Inserted ICD-10 codes for Discharge Record ID: 86641
# Processing Record ID: 179449
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['M16.12', 'Z87.39', 'I48.0', 'F32.9', 'S72.141']
# Cleaned ICD-10 Codes: ['M1612', 'Z8739', 'I480', 'F329', 'S72141']
# Inserted ICD-10 codes for Discharge Record ID: 179449
# Processing Record ID: 232535
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['E11.9', 'I10', 'N18.5', 'I21.9', 'Z49.31']
# Cleaned ICD-10 Codes: ['E119', 'I10', 'N185', 'I219', 'Z4931']
# Inserted ICD-10 codes for Discharge Record ID: 232535
# Processing Record ID: 144210
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['G40.909', 'R56.9', 'G43.009', 'N18.9', 'F45.41']
# Cleaned ICD-10 Codes: ['G40909', 'R569', 'G43009', 'N189', 'F4541']
# Inserted ICD-10 codes for Discharge Record ID: 144210
# Processing Record ID: 165723
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['M62.81', 'I48.2', 'I10', 'I25.10', 'E79.0']
# Cleaned ICD-10 Codes: ['M6281', 'I482', 'I10', 'I2510', 'E790']
# Inserted ICD-10 codes for Discharge Record ID: 165723
# Processing Record ID: 276092
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['S32.401A', 'M48.121', 'I48.0', 'E78.5', 'T88.6XXA']
# Cleaned ICD-10 Codes: ['S32401A', 'M48121', 'I480', 'E785', 'T886XXA']
# Inserted ICD-10 codes for Discharge Record ID: 276092
# Processing Record ID: 258188
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I48.2', 'Z95.5', 'I25.10', 'E11.9', 'I10']
# Cleaned ICD-10 Codes: ['I482', 'Z955', 'I2510', 'E119', 'I10']
# Inserted ICD-10 codes for Discharge Record ID: 258188
# Processing Record ID: 137571
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['J96.01', 'I50.21', 'F31.9', 'I25.10', 'G47.33']
# Cleaned ICD-10 Codes: ['J9601', 'I5021', 'F319', 'I2510', 'G4733']
# Inserted ICD-10 codes for Discharge Record ID: 137571
# Processing Record ID: 126189
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K81.0', 'K80.20', 'R10.9', 'Z48.2', 'Z87.19']
# Cleaned ICD-10 Codes: ['K810', 'K8020', 'R109', 'Z482', 'Z8719']
# Inserted ICD-10 codes for Discharge Record ID: 126189
# Processing Record ID: 122840
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['R07.9', 'F31.9', 'F90.9', 'J45.909', 'F14.10']
# Cleaned ICD-10 Codes: ['R079', 'F319', 'F909', 'J45909', 'F1410']
# Inserted ICD-10 codes for Discharge Record ID: 122840
# Processing Record ID: 72740
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I50.9', 'J81.1', 'R06.00', 'E11.9', 'I48.0']
# Cleaned ICD-10 Codes: ['I509', 'J811', 'R0600', 'E119', 'I480']
# Inserted ICD-10 codes for Discharge Record ID: 72740
# Processing Record ID: 14030
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['R26.0', 'G89.4', 'B20', 'M47.817', 'R51']
# Cleaned ICD-10 Codes: ['R260', 'G894', 'B20', 'M47817', 'R51']
# Inserted ICD-10 codes for Discharge Record ID: 14030
# Processing Record ID: 54456
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I61.0', 'G81.9', 'D64.9', 'I77.0', 'E87.4']
# Cleaned ICD-10 Codes: ['I610', 'G819', 'D649', 'I770', 'E874']
# Inserted ICD-10 codes for Discharge Record ID: 54456
# Processing Record ID: 186207
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K92.0', 'R04.0', 'G40.9', 'F32.9', 'E87.4']
# Cleaned ICD-10 Codes: ['K920', 'R040', 'G409', 'F329', 'E874']
# Inserted ICD-10 codes for Discharge Record ID: 186207
# Processing Record ID: 70427
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['G45.409', 'C43.9', 'I64', 'R51', 'F10.9']
# Cleaned ICD-10 Codes: ['G45409', 'C439', 'I64', 'R51', 'F109']
# Inserted ICD-10 codes for Discharge Record ID: 70427
# Processing Record ID: 69387
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['R55', 'I49.8', 'Z94.0', 'I25.10', 'G20.9']
# Cleaned ICD-10 Codes: ['R55', 'I498', 'Z940', 'I2510', 'G209']
# Inserted ICD-10 codes for Discharge Record ID: 69387
# Processing Record ID: 63638
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['O26.893', 'R51', 'F41.9', 'Z87.4', 'O80.00']
# Cleaned ICD-10 Codes: ['O26893', 'R51', 'F419', 'Z874', 'O8000']
# Inserted ICD-10 codes for Discharge Record ID: 63638
# Processing Record ID: 206150
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['F10.164', 'F10.20', 'R44.1', 'T51.0X', 'N30.0']
# Cleaned ICD-10 Codes: ['F10164', 'F1020', 'R441', 'T510X', 'N300']
# Inserted ICD-10 codes for Discharge Record ID: 206150
# Processing Record ID: 99118
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['F11.20', 'F43.12', 'F32.9', 'I10', 'E78.5']
# Cleaned ICD-10 Codes: ['F1120', 'F4312', 'F329', 'I10', 'E785']
# Inserted ICD-10 codes for Discharge Record ID: 99118
# Processing Record ID: 228596
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K70.3', 'F10.129', 'K74.0', 'R55', 'E87.1']
# Cleaned ICD-10 Codes: ['K703', 'F10129', 'K740', 'R55', 'E871']
# Inserted ICD-10 codes for Discharge Record ID: 228596
# Processing Record ID: 64581
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['A41.51', 'J18.1', 'N30.0', 'C71.1', 'E11.9']
# Cleaned ICD-10 Codes: ['A4151', 'J181', 'N300', 'C711', 'E119']
# Inserted ICD-10 codes for Discharge Record ID: 64581
# Processing Record ID: 31895
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['J18.9', 'R57.2', 'N17.9', 'I48.2', 'M79.1']
# Cleaned ICD-10 Codes: ['J189', 'R572', 'N179', 'I482', 'M791']
# Inserted ICD-10 codes for Discharge Record ID: 31895
# Processing Record ID: 66164
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['T39.1X1A', 'K71.11', 'F12.20', 'R78.1', 'Z91.19']
# Cleaned ICD-10 Codes: ['T391X1A', 'K7111', 'F1220', 'R781', 'Z9119']
# Inserted ICD-10 codes for Discharge Record ID: 66164
# Processing Record ID: 233394
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I47.1', 'I10', 'E03.9', 'K76.0', 'R00.0']
# Cleaned ICD-10 Codes: ['I471', 'I10', 'E039', 'K760', 'R000']
# Inserted ICD-10 codes for Discharge Record ID: 233394
# Processing Record ID: 50568
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['S05.41XA', 'H44.501', 'T81.41XA', 'Z87.39', 'H02.403']
# Cleaned ICD-10 Codes: ['S0541XA', 'H44501', 'T8141XA', 'Z8739', 'H02403']
# Inserted ICD-10 codes for Discharge Record ID: 50568
# Processing Record ID: 129895
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I21.4', 'I50.9', 'E11.9', 'I10', 'G43.909']
# Cleaned ICD-10 Codes: ['I214', 'I509', 'E119', 'I10', 'G43909']
# Inserted ICD-10 codes for Discharge Record ID: 129895
# Processing Record ID: 236815
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['O00.10', 'O00.90', 'Z32.01', 'T85.618', 'R10.2']
# Cleaned ICD-10 Codes: ['O0010', 'O0090', 'Z3201', 'T85618', 'R102']
# Inserted ICD-10 codes for Discharge Record ID: 236815
# Processing Record ID: 177751
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['C79.51', 'M96.1', 'C50.919', 'M84.49', 'G89.3']
# Cleaned ICD-10 Codes: ['C7951', 'M961', 'C50919', 'M8449', 'G893']
# Inserted ICD-10 codes for Discharge Record ID: 177751
# Processing Record ID: 257169
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['C37.9', 'I26.99', 'B96.21', 'J44.1', 'T81.4']
# Cleaned ICD-10 Codes: ['C379', 'I2699', 'B9621', 'J441', 'T814']
# Inserted ICD-10 codes for Discharge Record ID: 257169
# Processing Record ID: 98898
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['T43.603A', 'I25.10', 'I10', 'E78.5', 'R00.0']
# Cleaned ICD-10 Codes: ['T43603A', 'I2510', 'I10', 'E785', 'R000']
# Inserted ICD-10 codes for Discharge Record ID: 98898
# Processing Record ID: 212180
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K26.9', 'E27.4', 'A04.7', 'K29.0', 'F45.3']
# Cleaned ICD-10 Codes: ['K269', 'E274', 'A047', 'K290', 'F453']
# Inserted ICD-10 codes for Discharge Record ID: 212180
# Processing Record ID: 222991
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I26.09', 'I63.0', 'I48.0', 'E03.9', 'G31.83']
# Cleaned ICD-10 Codes: ['I2609', 'I630', 'I480', 'E039', 'G3183']
# Inserted ICD-10 codes for Discharge Record ID: 222991
# Processing Record ID: 13222
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K29.0', 'K50.1', 'G43.89', 'K57.32', 'R10.9']
# Cleaned ICD-10 Codes: ['K290', 'K501', 'G4389', 'K5732', 'R109']
# Inserted ICD-10 codes for Discharge Record ID: 13222
# Processing Record ID: 174425
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['C11.0', 'J06.9', 'E87.1', 'K12.1', 'B18.1']
# Cleaned ICD-10 Codes: ['C110', 'J069', 'E871', 'K121', 'B181']
# Inserted ICD-10 codes for Discharge Record ID: 174425
# Processing Record ID: 228256
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['R07.9', 'I10', 'E11.9', 'J44.9', 'I73.9']
# Cleaned ICD-10 Codes: ['R079', 'I10', 'E119', 'J449', 'I739']
# Inserted ICD-10 codes for Discharge Record ID: 228256
# Processing Record ID: 261262
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['E11.9', 'I50.9', 'N18.6', 'R55', 'E16.1']
# Cleaned ICD-10 Codes: ['E119', 'I509', 'N186', 'R55', 'E161']
# Inserted ICD-10 codes for Discharge Record ID: 261262
# Processing Record ID: 44446
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['F10.129', 'T50.911', 'G31.82', 'M47.817', 'F43.23']
# Cleaned ICD-10 Codes: ['F10129', 'T50911', 'G3182', 'M47817', 'F4323']
# Inserted ICD-10 codes for Discharge Record ID: 44446
# Processing Record ID: 185568
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['E11.1', 'I21.4', 'I25.10', 'E08.1', 'R11']
# Cleaned ICD-10 Codes: ['E111', 'I214', 'I2510', 'E081', 'R11']
# Inserted ICD-10 codes for Discharge Record ID: 185568
# Processing Record ID: 161383
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['S06.5X0A', 'S02.2XXA', 'S22.400A', 'D49.2', 'C50.919']
# Cleaned ICD-10 Codes: ['S065X0A', 'S022XXA', 'S22400A', 'D492', 'C50919']
# Inserted ICD-10 codes for Discharge Record ID: 161383
# Processing Record ID: 184851
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K51.90', 'R11.0', 'T81.41XA', 'D64.9', 'K59.0']
# Cleaned ICD-10 Codes: ['K5190', 'R110', 'T8141XA', 'D649', 'K590']
# Inserted ICD-10 codes for Discharge Record ID: 184851
# Processing Record ID: 13699
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['S02.63XA', 'S02.6XXA', 'T14.91XA', 'M26.609', 'Z87.39']
# Cleaned ICD-10 Codes: ['S0263XA', 'S026XXA', 'T1491XA', 'M26609', 'Z8739']
# Inserted ICD-10 codes for Discharge Record ID: 13699
# Processing Record ID: 182621
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['R65.20', 'T81.1', 'K65', 'I31.3', 'R09.02']
# Cleaned ICD-10 Codes: ['R6520', 'T811', 'K65', 'I313', 'R0902']
# Inserted ICD-10 codes for Discharge Record ID: 182621
# Processing Record ID: 219592
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['M79.1', 'I25.10', 'I10', 'E03.9', 'S62.139A']
# Cleaned ICD-10 Codes: ['M791', 'I2510', 'I10', 'E039', 'S62139A']
# Inserted ICD-10 codes for Discharge Record ID: 219592
# Processing Record ID: 89252
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I26.99', 'F10.129', 'K70.40', 'I50.9', 'Z51.89']
# Cleaned ICD-10 Codes: ['I2699', 'F10129', 'K7040', 'I509', 'Z5189']
# Inserted ICD-10 codes for Discharge Record ID: 89252
# Processing Record ID: 12172
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['C18.7', 'K56.7', 'C78.7', 'K65', 'I82.3']
# Cleaned ICD-10 Codes: ['C187', 'K567', 'C787', 'K65', 'I823']
# Inserted ICD-10 codes for Discharge Record ID: 12172
# Processing Record ID: 42563
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['R10.9', 'G80.1', 'E87.4', 'I10', 'K92.0']
# Cleaned ICD-10 Codes: ['R109', 'G801', 'E874', 'I10', 'K920']
# Inserted ICD-10 codes for Discharge Record ID: 42563
# Processing Record ID: 142846
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['C71.1', 'T85.619', 'I25.10', 'C79.71', 'G47.4']
# Cleaned ICD-10 Codes: ['C711', 'T85619', 'I2510', 'C7971', 'G474']
# Inserted ICD-10 codes for Discharge Record ID: 142846
# Processing Record ID: 297850
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['G30.9', 'M47.817', 'I42.0', 'E87.1', 'R26.0']
# Cleaned ICD-10 Codes: ['G309', 'M47817', 'I420', 'E871', 'R260']
# Inserted ICD-10 codes for Discharge Record ID: 297850
# Processing Record ID: 166710
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['C18.4', 'D50.0', 'I25.10', 'K21.9', 'R06.00']
# Cleaned ICD-10 Codes: ['C184', 'D500', 'I2510', 'K219', 'R0600']
# Inserted ICD-10 codes for Discharge Record ID: 166710
# Processing Record ID: 40821
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['J18.1', 'R05', 'R50.9', 'J12.9', 'G43.911']
# Cleaned ICD-10 Codes: ['J181', 'R05', 'R509', 'J129', 'G43911']
# Inserted ICD-10 codes for Discharge Record ID: 40821
# Processing Record ID: 152475
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K92.0', 'R11', 'F41.9', 'B20', 'E43']
# Cleaned ICD-10 Codes: ['K920', 'R11', 'F419', 'B20', 'E43']
# Inserted ICD-10 codes for Discharge Record ID: 152475
# Processing Record ID: 136121
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['C85.10', 'C83.31', 'I21.4', 'K29.0', 'E78.5']
# Cleaned ICD-10 Codes: ['C8510', 'C8331', 'I214', 'K290', 'E785']
# Inserted ICD-10 codes for Discharge Record ID: 136121
# Processing Record ID: 84903
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['G43.809', 'E87.4', 'R51', 'H93.19', 'E83.39']
# Cleaned ICD-10 Codes: ['G43809', 'E874', 'R51', 'H9319', 'E8339']
# Inserted ICD-10 codes for Discharge Record ID: 84903
# Processing Record ID: 245778
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I50.41', 'R53.83', 'E87.70', 'D64.9', 'J11.09']
# Cleaned ICD-10 Codes: ['I5041', 'R5383', 'E8770', 'D649', 'J1109']
# Inserted ICD-10 codes for Discharge Record ID: 245778
# Processing Record ID: 211090
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K56.7', 'C91.3', 'I21.4', 'K80.20', 'R10.9']
# Cleaned ICD-10 Codes: ['K567', 'C913', 'I214', 'K8020', 'R109']
# Inserted ICD-10 codes for Discharge Record ID: 211090
# Processing Record ID: 277964
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['M75.12', 'M75.22', 'S46.011A', 'M79.1', 'E53.9']
# Cleaned ICD-10 Codes: ['M7512', 'M7522', 'S46011A', 'M791', 'E539']
# Inserted ICD-10 codes for Discharge Record ID: 277964
# Processing Record ID: 178695
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K85.00', 'E11.9', 'N18.6', 'I48.0', 'K91.89']
# Cleaned ICD-10 Codes: ['K8500', 'E119', 'N186', 'I480', 'K9189']
# Inserted ICD-10 codes for Discharge Record ID: 178695
# Processing Record ID: 235762
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K59.1', 'E11.65', 'G62.1', 'F45.4', 'A04.7']
# Cleaned ICD-10 Codes: ['K591', 'E1165', 'G621', 'F454', 'A047']
# Inserted ICD-10 codes for Discharge Record ID: 235762
# Processing Record ID: 200003
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['O34.21', 'D62', 'Z37.0', 'F41.9', 'O75.1']
# Cleaned ICD-10 Codes: ['O3421', 'D62', 'Z370', 'F419', 'O751']
# Inserted ICD-10 codes for Discharge Record ID: 200003
# Processing Record ID: 43231
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['R41.82', 'I95.2', 'N17.9', 'I50.4', 'C61']
# Cleaned ICD-10 Codes: ['R4182', 'I952', 'N179', 'I504', 'C61']
# Inserted ICD-10 codes for Discharge Record ID: 43231
# Processing Record ID: 207219
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K81.1', 'K80.20', 'F31.9', 'F41.9', 'R10.9']
# Cleaned ICD-10 Codes: ['K811', 'K8020', 'F319', 'F419', 'R109']
# Inserted ICD-10 codes for Discharge Record ID: 207219
# Processing Record ID: 132009
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['G81.1', 'I63.0', 'I67.1', 'M79.1', 'Z87.39']
# Cleaned ICD-10 Codes: ['G811', 'I630', 'I671', 'M791', 'Z8739']
# Inserted ICD-10 codes for Discharge Record ID: 132009
# Processing Record ID: 196141
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['S32.89XA', 'S22.4XXA', 'S31.83XA', 'T81.013A', 'J95.89']
# Cleaned ICD-10 Codes: ['S3289XA', 'S224XXA', 'S3183XA', 'T81013A', 'J9589']
# Inserted ICD-10 codes for Discharge Record ID: 196141
# Processing Record ID: 114386
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K63.0', 'B37.7', 'K81.1', 'I50.4', 'G81.9']
# Cleaned ICD-10 Codes: ['K630', 'B377', 'K811', 'I504', 'G819']
# Inserted ICD-10 codes for Discharge Record ID: 114386
# Processing Record ID: 130467
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['R32', 'I69.191', 'N30.0', 'E78.5', 'R41.82']
# Cleaned ICD-10 Codes: ['R32', 'I69191', 'N300', 'E785', 'R4182']
# Inserted ICD-10 codes for Discharge Record ID: 130467
# Processing Record ID: 130450
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I46.9', 'I50.41', 'Q22.5', 'E11.9', 'I42.8']
# Cleaned ICD-10 Codes: ['I469', 'I5041', 'Q225', 'E119', 'I428']
# Inserted ICD-10 codes for Discharge Record ID: 130450
# Processing Record ID: 50535
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I63.4', 'I65.29', 'E11.9', 'E78.5', 'R42']
# Cleaned ICD-10 Codes: ['I634', 'I6529', 'E119', 'E785', 'R42']
# Inserted ICD-10 codes for Discharge Record ID: 50535
# Processing Record ID: 255383
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['M86.671', 'E11.9', 'I10', 'F32.9', 'K21.9']
# Cleaned ICD-10 Codes: ['M86671', 'E119', 'I10', 'F329', 'K219']
# Inserted ICD-10 codes for Discharge Record ID: 255383
# Processing Record ID: 270988
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['G81.1', 'I60.2', 'T85.619', 'R01.1', 'F11.2']
# Cleaned ICD-10 Codes: ['G811', 'I602', 'T85619', 'R011', 'F112']
# Inserted ICD-10 codes for Discharge Record ID: 270988
# Processing Record ID: 52080
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I71.01', 'I72.3', 'R07.1', 'I10', 'Z95.828']
# Cleaned ICD-10 Codes: ['I7101', 'I723', 'R071', 'I10', 'Z95828']
# Inserted ICD-10 codes for Discharge Record ID: 52080
# Processing Record ID: 153267
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['C04.1', 'K52.9', 'R55', 'S82.01A', 'I21.4']
# Cleaned ICD-10 Codes: ['C041', 'K529', 'R55', 'S8201A', 'I214']
# Inserted ICD-10 codes for Discharge Record ID: 153267
# Processing Record ID: 273797
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K81.0', 'K80.20', 'R10.9', 'Z87.19', 'N30.0']
# Cleaned ICD-10 Codes: ['K810', 'K8020', 'R109', 'Z8719', 'N300']
# Inserted ICD-10 codes for Discharge Record ID: 273797
# Processing Record ID: 319489
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I50.21', 'I25.10', 'J44.9', 'I10', 'E11.9']
# Cleaned ICD-10 Codes: ['I5021', 'I2510', 'J449', 'I10', 'E119']
# Inserted ICD-10 codes for Discharge Record ID: 319489
# Processing Record ID: 264912
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I21.4', 'Z95.5', 'I25.10', 'I48.0', 'Q61.1']
# Cleaned ICD-10 Codes: ['I214', 'Z955', 'I2510', 'I480', 'Q611']
# Inserted ICD-10 codes for Discharge Record ID: 264912
# Processing Record ID: 201126
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['D12.6', 'K63.9', 'Z85.812', 'Z87.39', 'R10.9']
# Cleaned ICD-10 Codes: ['D126', 'K639', 'Z85812', 'Z8739', 'R109']
# Inserted ICD-10 codes for Discharge Record ID: 201126
# Processing Record ID: 297177
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I21.4', 'I25.10', 'I10', 'Z95.5', 'R07.1']
# Cleaned ICD-10 Codes: ['I214', 'I2510', 'I10', 'Z955', 'R071']
# Inserted ICD-10 codes for Discharge Record ID: 297177
# Processing Record ID: 248507
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['M96.1', 'I25.10', 'E78.5', 'G47.33', 'K21.9']
# Cleaned ICD-10 Codes: ['M961', 'I2510', 'E785', 'G4733', 'K219']
# Inserted ICD-10 codes for Discharge Record ID: 248507
# Processing Record ID: 141605
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# ...
# Processing Record ID: 79265
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K76.1', 'K74.0', 'D86.0', 'I87.2', 'R11']
# Cleaned ICD-10 Codes: ['K761', 'K740', 'D860', 'I872', 'R11']
# Inserted ICD-10 codes for Discharge Record ID: 79265
# Processing Record ID: 267313
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I21.4', 'I50.9', 'Z95.2', 'E78.5', 'I10']
# Cleaned ICD-10 Codes: ['I214', 'I509', 'Z952', 'E785', 'I10']
# Inserted ICD-10 codes for Discharge Record ID: 267313
# Processing Record ID: 38554
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['L03.116', 'R30.0', 'I49.5', 'C34.12', 'N30.0']
# Cleaned ICD-10 Codes: ['L03116', 'R300', 'I495', 'C3412', 'N300']
# Inserted ICD-10 codes for Discharge Record ID: 38554
# Processing Record ID: 39031
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['E86', 'K50.00', 'E27.4', 'M35.9', 'Z91.89']
# Cleaned ICD-10 Codes: ['E86', 'K5000', 'E274', 'M359', 'Z9189']
# Inserted ICD-10 codes for Discharge Record ID: 39031
# Processing Record ID: 175317
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['E46', 'K76.1', 'I89.4', 'G62.9', 'F32.9']
# Cleaned ICD-10 Codes: ['E46', 'K761', 'I894', 'G629', 'F329']
# Inserted ICD-10 codes for Discharge Record ID: 175317
# Processing Record ID: 215595
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K76.1', 'I10', 'N18.9', 'E87.5', 'K72.1']
# Cleaned ICD-10 Codes: ['K761', 'I10', 'N189', 'E875', 'K721']
# Inserted ICD-10 codes for Discharge Record ID: 215595
# Processing Record ID: 200707
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K35.80', 'E11.9', 'K51.90', 'R10.9', 'Z85.812']
# Cleaned ICD-10 Codes: ['K3580', 'E119', 'K5190', 'R109', 'Z85812']
# Inserted ICD-10 codes for Discharge Record ID: 200707
# Processing Record ID: 26259
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I50.221', 'K21.9', 'R13.10', 'I48', 'E46']
# Cleaned ICD-10 Codes: ['I50221', 'K219', 'R1310', 'I48', 'E46']
# Inserted ICD-10 codes for Discharge Record ID: 26259
# Processing Record ID: 174589
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['F11.129', 'T36.908D', 'O99.32', 'F43.23', 'Z91.19']
# Cleaned ICD-10 Codes: ['F11129', 'T36908D', 'O9932', 'F4323', 'Z9119']
# Inserted ICD-10 codes for Discharge Record ID: 174589
# Processing Record ID: 93052
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['K63.1', 'T81.31', 'C21.1', 'K59.0', 'R50.9']
# Cleaned ICD-10 Codes: ['K631', 'T8131', 'C211', 'K590', 'R509']
# Inserted ICD-10 codes for Discharge Record ID: 93052
# Processing Record ID: 179627
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['F33.1', 'F41.0', 'E11.9', 'I25.10', 'F40.01']
# Cleaned ICD-10 Codes: ['F331', 'F410', 'E119', 'I2510', 'F4001']
# Inserted ICD-10 codes for Discharge Record ID: 179627
# Processing Record ID: 185120
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['G24.3', 'M54.2', 'E85.0', 'J45.909', 'F43.8']
# Cleaned ICD-10 Codes: ['G243', 'M542', 'E850', 'J45909', 'F438']
# Inserted ICD-10 codes for Discharge Record ID: 185120
# Processing Record ID: 216404
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['J84.112', 'K70.30', 'I10', 'E78.5', 'K74.01']
# Cleaned ICD-10 Codes: ['J84112', 'K7030', 'I10', 'E785', 'K7401']
# Inserted ICD-10 codes for Discharge Record ID: 216404
# Processing Record ID: 16865
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I21.4', 'I50.42', 'I10', 'I48.0', 'E11.9']
# Cleaned ICD-10 Codes: ['I214', 'I5042', 'I10', 'I480', 'E119']
# Inserted ICD-10 codes for Discharge Record ID: 16865
# Processing Record ID: 82147
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I49.5', 'R55', 'G31.83', 'I10', 'F01.50']
# Cleaned ICD-10 Codes: ['I495', 'R55', 'G3183', 'I10', 'F0150']
# Inserted ICD-10 codes for Discharge Record ID: 82147
# Processing Record ID: 326292
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['C72.40', 'G93.2', 'R51', 'I67.1', 'F06.9']
# Cleaned ICD-10 Codes: ['C7240', 'G932', 'R51', 'I671', 'F069']
# Inserted ICD-10 codes for Discharge Record ID: 326292
# Processing Record ID: 250411
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I21.4', 'I10', 'E11.9', 'J44.9', 'I50.4']
# Cleaned ICD-10 Codes: ['I214', 'I10', 'E119', 'J449', 'I504']
# Inserted ICD-10 codes for Discharge Record ID: 250411
# Processing Record ID: 15480
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I21.4', 'I25.10', 'E11.9', 'K57.32', 'N40.1']
# Cleaned ICD-10 Codes: ['I214', 'I2510', 'E119', 'K5732', 'N401']
# Inserted ICD-10 codes for Discharge Record ID: 15480
# Processing Record ID: 100649
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['E10.1', 'N10', 'R42', 'E87.4', 'T14.9']
# Cleaned ICD-10 Codes: ['E101', 'N10', 'R42', 'E874', 'T149']
# Inserted ICD-10 codes for Discharge Record ID: 100649
# Processing Record ID: 268823
# Calling LLM for ICD-10 code generation...
# Parsing ICD-10 codes...
# Cleaning ICD-10 codes...
# Raw ICD-10 Codes: ['I63.50', 'I65.281', 'C61', 'G81.91', 'R29.709']
# Cleaned ICD-10 Codes: ['I6350', 'I65281', 'C61', 'G8191', 'R29709']
# Inserted ICD-10 codes for Discharge Record ID: 268823
# Processing Record ID: 201139
# Calling LLM for ICD-10 code generation...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 4
#       2 if __name__ == "__main__":
#       3     print("Starting discharge note processing...")
# ----> 4     process_discharge_notes()
#       5     print("Discharge note processing finished.")
#
# Cell In[40], line 19, in process_discharge_notes()
#      16 print(f"Processing Record ID: {dis_record_id}")
#      18 # Generate ICD-10 codes
# ---> 19 raw_icd_codes = call_llm_for_icd(clinical_note)
#      20 cleaned_icd_codes = clean_icd_codes(raw_icd_codes)
#      22 print(f"Raw ICD-10 Codes: {raw_icd_codes}")
#
# Cell In[37], line 32, in call_llm_for_icd(clinical_note)
#      30 # LLM API Call
#      31 messages = [{"role": "user", "content": prompt_medical_code}]
# ---> 32 completion = client.chat.completions.create(
#      33     model="meta-llama/Llama-3.3-70B-Instruct",
#      34     messages=messages,
#      35     max_tokens=500
#      36 )
#      38 # Parse the response
#      39 icd_codes = completion.choices[0].message["content"]
#
# File ~/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages/huggingface_hub/inference/_client.py:882, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p)
#     860 payload = dict(
#     861     model=model_id,
#     862     messages=messages,
#    (...)
#     879     stream_options=stream_options,
#     880 )
#     881 payload = {key: value for key, value in payload.items() if value is not None}
# --> 882 data = self.post(model=model_url, json=payload, stream=stream)
#     884 if stream:
#     885     return _stream_chat_completion_response(data)  # type: ignore[arg-type]
#
# File ~/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages/huggingface_hub/inference/_client.py:281, in InferenceClient.post(self, json, data, model, task, stream)
#     279 with _open_as_binary(data) as data_as_binary:
#     280     try:
# --> 281         response = get_session().post(
#     282             url,
#     283             json=json,
#     284             data=data_as_binary,
#     285             headers=headers,
#     286             cookies=self.cookies,
#     287             timeout=self.timeout,
#     288             stream=stream,
#     289             proxies=self.proxies,
#     290         )
#     291     except TimeoutError as error:
#     292         # Convert any `TimeoutError` to a `InferenceTimeoutError`
#     293         raise InferenceTimeoutError(f"Inference call timed out: {url}") from error  # type: ignore
#
# File ~/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages/huggingface_hub/utils/_http.py:93, in UniqueRequestIdAdapter.send(self, request, *args, **kwargs)
#      91 """Catch any RequestException to append request id to the error message for debugging."""
#      92 try:
# ---> 93     return super().send(request, *args, **kwargs)
#      94 except requests.RequestException as e:
#      95     request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# File ~/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:716, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713     self._prepare_proxy(conn)
#     715 # Make the request on the httplib connection object.
# --> 716 httplib_response = self._make_request(
#     717     conn,
#     718     method,
#     719     url,
#     720     timeout=timeout_obj,
#     721     body=body,
#     722     headers=headers,
#     723     chunked=chunked,
#     724 )
#     726 # If we're going to release the connection in ``finally:``, then
#     727 # the response doesn't need to know about the connection. Otherwise
#     728 # it will also try to release it and we'll have a double-release
#     729 # mess.
#     730 response_conn = conn if not release_conn else None
#
# File ~/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     463             httplib_response = conn.getresponse()
#     464         except BaseException as e:
#     465             # Remove the TypeError from the exception chain in
#     466             # Python 3 (including for exceptions like SystemExit).
#     467             # Otherwise it looks like a bug in the code.
# --> 468             six.raise_from(e, None)
#     469 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     470     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/Desktop/Start-to-Complete/MediAssist-Healthcare-Data-Solutions/.venv/lib/python3.9/site-packages/urllib3/connectionpool.py:463, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 except TypeError:
#     461     # Python 3
#     462     try:
# --> 463         httplib_response = conn.getresponse()
#     464     except BaseException as e:
#     465         # Remove the TypeError from the exception chain in
#     466         # Python 3 (including for exceptions like SystemExit).
#     467         # Otherwise it looks like a bug in the code.
#     468         six.raise_from(e, None)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.20/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /opt/homebrew/Cellar/python@3.9/3.9.20/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /opt/homebrew/Cellar/python@3.9/3.9.20/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.9/3.9.20/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:716, in SocketIO.readinto(self, b)
#     714 while True:
#     715     try:
# --> 716         return self._sock.recv_into(b)
#     717     except timeout:
#     718         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.9/3.9.20/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1275, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271     if flags != 0:
#    1272         raise ValueError(
#    1273           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1274           self.__class__)
# -> 1275     return self.read(nbytes, buffer)
#    1276 else:
#    1277     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.9/3.9.20/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1133, in SSLSocket.read(self, len, buffer)
#    1131 try:
#    1132     if buffer is not None:
# -> 1133         return self._sslobj.read(len, buffer)
#    1134     else:
#    1135         return self._sslobj.read(len)
#
# KeyboardInterrupt:
