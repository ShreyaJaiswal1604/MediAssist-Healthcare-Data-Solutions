# %%
import snowflake.snowpark as snowpark
from snowflake.snowpark import Session

# %%
# Testing the functions in the notebook
user = 'DOLPHIN'
password = 'Maapaa@1603'  # Avoid hardcoding sensitive information
account = 'URB63596'
database = 'mimic_iv_medi_assist'
schema = 'raw'
warehouse = 'my_warehouse'

# %%
# Internal stage name
STAGE_NAME = 'my_internal_stage'

# %%
# CSV files and their naming conventions
TABLES_TO_LOAD = [
    'admissions.csv.gz',
    'd_icd_diagnoses.csv.gz',
    'd_icd_procedures.csv.gz',
    'discharge.csv.gz',
    'drgcodes.csv.gz',
    'pharmacy.csv.gz',
]

# %%
# Function to establish Snowflake session
def create_session(user, password, account, database, schema):
    connection_parameters = {
        "user": user,
        "password": password,
        "account": account,
        "database": database,
        "schema": schema,
    }
    return Session.builder.configs(connection_parameters).create()

# %%
session = create_session(user, password, account, database, schema)

# %%
print("Ensuring warehouse is active...")
session.sql(f"USE WAREHOUSE {warehouse};").collect()

for file in TABLES_TO_LOAD:
    table_name = f"{file.split('.')[0]}"  # Remove .gz extension
    print(f"Creating table: {table_name} from file: {file}")

    location = f'@{STAGE_NAME}/{file}'  # Reference to internal stage
    print("=================================================================================\n")
    print(f"Loading data into '{table_name}' from {location}...")

    try:
        # Load data into the Snowflake table using the COPY INTO command with ON_ERROR
        session.sql(f"""
            COPY INTO {table_name}
            FROM {location};
        """).collect()

        print(f"Data loaded into table '{table_name}' successfully.")
    except Exception as e:
        print(f"Error loading data into '{table_name}': {e}")
    print("=================================================================================\n")
# Out:
# Ensuring warehouse is active...
# Creating table: admissions from file: admissions.csv.gz
# =================================================================================
#
# Loading data into 'admissions' from @my_internal_stage/admissions.csv.gz...
# Error loading data into 'admissions': (1304): 01b793b4-0003-a868-0000-13e7001151ba: 001757 (42601): SQL compilation error:
# Table 'ADMISSIONS' does not exist
# =================================================================================
#
# Creating table: d_icd_diagnoses from file: d_icd_diagnoses.csv.gz
# =================================================================================
#
# Loading data into 'd_icd_diagnoses' from @my_internal_stage/d_icd_diagnoses.csv.gz...
# Error loading data into 'd_icd_diagnoses': (1304): 01b793b4-0003-a5ad-0000-13e700114666: 001757 (42601): SQL compilation error:
# Table 'D_ICD_DIAGNOSES' does not exist
# =================================================================================
#
# Creating table: d_icd_procedures from file: d_icd_procedures.csv.gz
# =================================================================================
#
# Loading data into 'd_icd_procedures' from @my_internal_stage/d_icd_procedures.csv.gz...
# Error loading data into 'd_icd_procedures': (1304): 01b793b5-0003-a868-0000-13e7001151be: 001757 (42601): SQL compilation error:
# Table 'D_ICD_PROCEDURES' does not exist
# =================================================================================
#
# Creating table: discharge from file: discharge.csv.gz
# =================================================================================
#
# Loading data into 'discharge' from @my_internal_stage/discharge.csv.gz...
# Error loading data into 'discharge': (1304): 01b793b5-0003-a5ad-0000-13e70011466a: 001757 (42601): SQL compilation error:
# Table 'DISCHARGE' does not exist
# =================================================================================
#
# Creating table: drgcodes from file: drgcodes.csv.gz
# =================================================================================
#
# Loading data into 'drgcodes' from @my_internal_stage/drgcodes.csv.gz...
# Error loading data into 'drgcodes': (1304): 01b793b5-0003-a868-0000-13e7001151c2: 001757 (42601): SQL compilation error:
# Table 'DRGCODES' does not exist
# =================================================================================
#
# Creating table: pharmacy from file: pharmacy.csv.gz
# =================================================================================
#
# Loading data into 'pharmacy' from @my_internal_stage/pharmacy.csv.gz...
# Error loading data into 'pharmacy': (1304): 01b793b5-0003-a5ad-0000-13e70011466e: 001757 (42601): SQL compilation error:
# Table 'PHARMACY' does not exist
# =================================================================================

# %%
# Create file format
def create_file_format(session):
    print("Creating file format...")
    session.sql("""
        CREATE OR REPLACE FILE FORMAT file_format_csv
        TYPE = 'CSV'
        COMPRESSION = 'GZIP'
        FIELD_DELIMITER = ','
        PARSE_HEADER = TRUE
        FIELD_OPTIONALLY_ENCLOSED_BY = '"';
    """).collect()
    print("File format 'file_format_csv' created successfully.")
    print("===========")

# %%
# Create table from inferred schema
def create_table(session, table_name, file_path):
    location = f'@{STAGE_NAME}/{file_path}'  # Reference to internal stage
    print(f"Creating table '{table_name}' with inferred schema from {location}...")

    try:
        session.sql(f"""
            CREATE OR REPLACE TABLE {table_name}
            USING TEMPLATE (
                SELECT ARRAY_AGG(OBJECT_CONSTRUCT(*))
                FROM TABLE(
                    INFER_SCHEMA(
                        LOCATION => '{location}',
                        FILE_FORMAT => 'file_format_csv',
                        ON_ERROR => 'CONTINUE'
                    )
                )
            );
        """).collect()

        print(f"Table '{table_name}' created successfully with inferred schema.")
    except Exception as e:
        print(f"Error creating table '{table_name}': {e}")
    print("===========\n\n")

# %%
# Load all raw tables
def load_all_raw_tables(session):
    print("Ensuring warehouse is active...")
    session.sql(f"USE WAREHOUSE 'my_warehouse';").collect()

    for file in TABLES_TO_LOAD:
        table_name = f"{file.split('.')[0]}"  # Remove .gz extension
        print(f"Creating table: {table_name} from file: {file}")
        create_table(session, table_name, file)

    print("All tables created successfully.")

# %%
# Create file format and load raw tables
create_file_format(session)
load_all_raw_tables(session)

# %% [markdown]
# ---
# AUTOMATE TEST SCRIPT
#
# ---

# %%
from snowflake.snowpark import Session
import os
from datetime import datetime

# %%
user = 'DOLPHIN'
password = 'Maapaa@1603'  # Avoid hardcoding sensitive information
account = 'URB63596'
database = 'mimic_iv_medi_assist'
schema = 'raw'
warehouse = 'my_warehouse'

# %%
def snowpark_basic_auth() -> Session:
    connection_parameters = {
        "ACCOUNT":"URB63596",
        "USER":"DOLPHIN",
        "PASSWORD":"Maapaa@1603"
    }
    return Session.builder.configs(connection_parameters).create()

# %%
def generate_ddl_statement(column_names, data_types, table_name):
    ddl_template = "CREATE TABLE IF NOT EXISTS {} (\n{})"
    columns = []
    for name, data_type in zip(column_names, data_types):
        column_definition = f"   {name} {data_type}"
        columns.append(column_definition)

    ddl_statement = ddl_template.format(table_name, ",\n".join(columns))
    return ddl_statement

# %%
def generate_copy_statement(table_name,stage_name,csv_file_path,file_format):
    copy_command = f"""
    COPY INTO {table_name}
    FROM @{stage_name}/{csv_file_path}
    FILE_FORMAT = (FORMAT_NAME = '{file_format}')
    ON_ERROR = 'CONTINUE';
    """

    return copy_command

# %%
def create_file_format(session):
    print("Creating file format...")
    session.sql("""
        CREATE OR REPLACE FILE FORMAT file_format_csv
        TYPE = 'CSV'
        COMPRESSION = 'GZIP'                   -- Specify GZIP compression for .gz files
        FIELD_DELIMITER = ','                   -- Specify the field delimiter
        PARSE_HEADER = TRUE                      -- Parse the header row for column names
        FIELD_OPTIONALLY_ENCLOSED_BY = '"';     -- Optional field enclosure
    """).collect()

    print("File format 'file_format_csv' created successfully.")
    print("===========")

# %%
def create_file_format(session):
    print("Creating file format for DDL...")
    session.sql("""
        CREATE OR REPLACE FILE FORMAT file_format_ddl
        TYPE = 'CSV'
        COMPRESSION = 'auto'                   -- Specify GZIP compression for .gz files
        FIELD_DELIMITER = ','                   -- Specify the field delimiter
        PARSE_HEADER = TRUE                    -- Parse the header row for column names
        FIELD_OPTIONALLY_ENCLOSED_BY = '\042'
        ESCAPE_UNENCLOSED_FIELD = NONE 
        TRIM_SPACE = TRUE 
        ERROR_ON_COLUMN_COUNT_MISMATCH = FALSE;
    """).collect()

    print("File format 'file_format_ddl' created successfully.")
    print("===========")

    session.sql("""
        CREATE OR REPLACE FILE FORMAT file_format_load
        TYPE = 'CSV'
        COMPRESSION = 'auto'                   -- Specify GZIP compression for .gz files
        FIELD_DELIMITER = ','                   -- Specify the field delimiter
        RECORD_DELIMITER = '\n' 
        SKIP_HEADER = 1                      -- Parse the header row for column names
        FIELD_OPTIONALLY_ENCLOSED_BY = '\042'     -- Optional field enclosure
        ;
    """).collect()

    print("File format 'file_format_load' created successfully.")
    print("===========")

# %%
utc_start_time = datetime.utcnow()
session_wih_pwd = snowpark_basic_auth()


session_wih_pwd.sql("USE DATABASE mimic_iv_medi_assist").collect()
session_wih_pwd.sql("USE SCHEMA raw").collect()
session_wih_pwd.sql("USE WAREHOUSE my_warehouse").collect()

create_file_format(session_wih_pwd)
# Out:
# Creating file format for DDL...
# File format 'file_format_ddl' created successfully.
# ===========
# File format 'file_format_load' created successfully.
# ===========

# %%
stg_files = session_wih_pwd.sql("list @my_internal_stage").collect()
print(stg_files)
# Out:
# [Row(name='my_internal_stage/admissions.csv.gz', size=19652448, md5='e030d760b3e15ce1c6aa9e8e8637ebcd', last_modified='Wed, 9 Oct 2024 06:45:27 GMT'), Row(name='my_internal_stage/d_icd_diagnoses.csv.gz', size=849392, md5='d77fe5f8249b16ed3692e52bd781dc06', last_modified='Wed, 9 Oct 2024 06:45:17 GMT'), Row(name='my_internal_stage/d_icd_procedures.csv.gz', size=549936, md5='d4a9b85d7ee6a75d32f6e1d61ac173cf', last_modified='Wed, 9 Oct 2024 06:44:37 GMT'), Row(name='my_internal_stage/discharge.csv.gz', size=126310544, md5='e7c7771791f2027cd839f138019523f0', last_modified='Wed, 9 Oct 2024 06:45:12 GMT'), Row(name='my_internal_stage/drgcodes.csv.gz', size=9509520, md5='89a92ba0a394557ceaa16cfcf7c93bce', last_modified='Wed, 9 Oct 2024 06:45:16 GMT'), Row(name='my_internal_stage/pharmacy.csv.gz', size=490336976, md5='a0750d0989ad0a5251c3ef42463974e8-59', last_modified='Wed, 9 Oct 2024 06:48:38 GMT')]

# %%
for row in stg_files:
    print("======================================================\n")
    print(row)
    row_value = row.as_dict()
    print(row_value)
    stg_file_path_value = row_value.get('name')
    print(stg_file_path_value)

    file_path, file_name = os.path.split(stg_file_path_value)
    print(file_path)
    print(file_name)
    if file_name == 'discharge.csv.gz' or file_name == 'pharmacy.csv.gz':
        continue
    
    stg_location = "@"+file_path
    print(stg_location)

    infer_schema_sql = """\
        SELECT * 
        FROM TABLE(
            INFER_SCHEMA(
            LOCATION=>'{}/',
            files => '{}',
            FILE_FORMAT => 'file_format_ddl'
        )    
    )
    """.format(stg_location, file_name)

    print(f"\n=========== INFER SCHEMA SQL =============")
    print(f" {file_name}")
    print(f"\n=========== INFER SCHEMA SQL =============")
    print(infer_schema_sql)

    inferred_schema_rows = session_wih_pwd.sql(infer_schema_sql).collect()
    print(inferred_schema_rows)
    col_name_lst = []
    col_data_type_lst = []

    for row in inferred_schema_rows:
        row_value = row.as_dict()
        print(row_value)
        column_name = row_value.get('COLUMN_NAME')
        column_type = row_value.get('TYPE')

        col_name_lst.append(column_name)
        col_data_type_lst.append(column_type)

    table_name = file_name.split('.')[0]+"_raw"
    create_ddl_stmt = generate_ddl_statement(col_name_lst,col_data_type_lst, table_name.upper())
    print("=================== DDL STATEMENT =====================")
    print(create_ddl_stmt)

    copy_stmt = generate_copy_statement(table_name, 'my_internal_stage', file_name, 'file_format_load')
    print("=================== copy_stmt =====================")
    print(copy_stmt)


    sql_file_path = table_name+".sql"
    print("=========================== sql_file_path =============================")
    print(f"{sql_file_path}")
    with open(sql_file_path, "w") as sql_file:
        sql_file.write("---- Following statement is creating table\n\n")
        sql_file.write(create_ddl_stmt)
        sql_file.write("\n-- Following statement is executing copy command")
        sql_file.write(copy_stmt)

    session_wih_pwd.sql(create_ddl_stmt).collect()
    session_wih_pwd.sql(copy_stmt).collect()
    utc_end_time = datetime.utcnow()

print(utc_end_time-utc_start_time)
# Out:
# ======================================================
#
# Row(name='my_internal_stage/admissions.csv.gz', size=19652448, md5='e030d760b3e15ce1c6aa9e8e8637ebcd', last_modified='Wed, 9 Oct 2024 06:45:27 GMT')
# {'name': 'my_internal_stage/admissions.csv.gz', 'size': 19652448, 'md5': 'e030d760b3e15ce1c6aa9e8e8637ebcd', 'last_modified': 'Wed, 9 Oct 2024 06:45:27 GMT'}
# my_internal_stage/admissions.csv.gz
# my_internal_stage
# admissions.csv.gz
# @my_internal_stage
#
# =========== INFER SCHEMA SQL =============
#  admissions.csv.gz
#
# =========== INFER SCHEMA SQL =============
#         SELECT *
#         FROM TABLE(
#             INFER_SCHEMA(
#             LOCATION=>'@my_internal_stage/',
#             files => 'admissions.csv.gz',
#             FILE_FORMAT => 'file_format_ddl'
#         )
#     )
#
# [Row(COLUMN_NAME='subject_id', TYPE='NUMBER(8, 0)', NULLABLE=True, EXPRESSION='$1::NUMBER(8, 0)', FILENAMES='admissions.csv.gz', ORDER_ID=0), Row(COLUMN_NAME='hadm_id', TYPE='NUMBER(8, 0)', NULLABLE=True, EXPRESSION='$2::NUMBER(8, 0)', FILENAMES='admissions.csv.gz', ORDER_ID=1), Row(COLUMN_NAME='admittime', TYPE='TIMESTAMP_NTZ', NULLABLE=True, EXPRESSION='$3::TIMESTAMP_NTZ', FILENAMES='admissions.csv.gz', ORDER_ID=2), Row(COLUMN_NAME='dischtime', TYPE='TIMESTAMP_NTZ', NULLABLE=True, EXPRESSION='$4::TIMESTAMP_NTZ', FILENAMES='admissions.csv.gz', ORDER_ID=3), Row(COLUMN_NAME='deathtime', TYPE='TIMESTAMP_NTZ', NULLABLE=True, EXPRESSION='$5::TIMESTAMP_NTZ', FILENAMES='admissions.csv.gz', ORDER_ID=4), Row(COLUMN_NAME='admission_type', TYPE='TEXT', NULLABLE=True, EXPRESSION='$6::TEXT', FILENAMES='admissions.csv.gz', ORDER_ID=5), Row(COLUMN_NAME='admit_provider_id', TYPE='TEXT', NULLABLE=True, EXPRESSION='$7::TEXT', FILENAMES='admissions.csv.gz', ORDER_ID=6), Row(COLUMN_NAME='admission_location', TYPE='TEXT', NULLABLE=True, EXPRESSION='$8::TEXT', FILENAMES='admissions.csv.gz', ORDER_ID=7), Row(COLUMN_NAME='discharge_location', TYPE='TEXT', NULLABLE=True, EXPRESSION='$9::TEXT', FILENAMES='admissions.csv.gz', ORDER_ID=8), Row(COLUMN_NAME='insurance', TYPE='TEXT', NULLABLE=True, EXPRESSION='$10::TEXT', FILENAMES='admissions.csv.gz', ORDER_ID=9), Row(COLUMN_NAME='language', TYPE='TEXT', NULLABLE=True, EXPRESSION='$11::TEXT', FILENAMES='admissions.csv.gz', ORDER_ID=10), Row(COLUMN_NAME='marital_status', TYPE='TEXT', NULLABLE=True, EXPRESSION='$12::TEXT', FILENAMES='admissions.csv.gz', ORDER_ID=11), Row(COLUMN_NAME='race', TYPE='TEXT', NULLABLE=True, EXPRESSION='$13::TEXT', FILENAMES='admissions.csv.gz', ORDER_ID=12), Row(COLUMN_NAME='edregtime', TYPE='TIMESTAMP_NTZ', NULLABLE=True, EXPRESSION='$14::TIMESTAMP_NTZ', FILENAMES='admissions.csv.gz', ORDER_ID=13), Row(COLUMN_NAME='edouttime', TYPE='TIMESTAMP_NTZ', NULLABLE=True, EXPRESSION='$15::TIMESTAMP_NTZ', FILENAMES='admissions.csv.gz', ORDER_ID=14), Row(COLUMN_NAME='hospital_expire_flag', TYPE='NUMBER(1, 0)', NULLABLE=True, EXPRESSION='$16::NUMBER(1, 0)', FILENAMES='admissions.csv.gz', ORDER_ID=15)]
# {'COLUMN_NAME': 'subject_id', 'TYPE': 'NUMBER(8, 0)', 'NULLABLE': True, 'EXPRESSION': '$1::NUMBER(8, 0)', 'FILENAMES': 'admissions.csv.gz', 'ORDER_ID': 0}
# {'COLUMN_NAME': 'hadm_id', 'TYPE': 'NUMBER(8, 0)', 'NULLABLE': True, 'EXPRESSION': '$2::NUMBER(8, 0)', 'FILENAMES': 'admissions.csv.gz', 'ORDER_ID': 1}
# {'COLUMN_NAME': 'admittime', 'TYPE': 'TIMESTAMP_NTZ', 'NULLABLE': True, 'EXPRESSION': '$3::TIMESTAMP_NTZ', 'FILENAMES': 'admissions.csv.gz', 'ORDER_ID': 2}
# {'COLUMN_NAME': 'dischtime', 'TYPE': 'TIMESTAMP_NTZ', 'NULLABLE': True, 'EXPRESSION': '$4::TIMESTAMP_NTZ', 'FILENAMES': 'admissions.csv.gz', 'ORDER_ID': 3}
# {'COLUMN_NAME': 'deathtime', 'TYPE': 'TIMESTAMP_NTZ', 'NULLABLE': True, 'EXPRESSION': '$5::TIMESTAMP_NTZ', 'FILENAMES': 'admissions.csv.gz', 'ORDER_ID': 4}
# {'COLUMN_NAME': 'admission_type', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$6::TEXT', 'FILENAMES': 'admissions.csv.gz', 'ORDER_ID': 5}
# {'COLUMN_NAME': 'admit_provider_id', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$7::TEXT', 'FILENAMES': 'admissions.csv.gz', 'ORDER_ID': 6}
# {'COLUMN_NAME': 'admission_location', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$8::TEXT', 'FILENAMES': 'admissions.csv.gz', 'ORDER_ID': 7}
# {'COLUMN_NAME': 'discharge_location', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$9::TEXT', 'FILENAMES': 'admissions.csv.gz', 'ORDER_ID': 8}
# {'COLUMN_NAME': 'insurance', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$10::TEXT', 'FILENAMES': 'admissions.csv.gz', 'ORDER_ID': 9}
# {'COLUMN_NAME': 'language', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$11::TEXT', 'FILENAMES': 'admissions.csv.gz', 'ORDER_ID': 10}
# {'COLUMN_NAME': 'marital_status', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$12::TEXT', 'FILENAMES': 'admissions.csv.gz', 'ORDER_ID': 11}
# {'COLUMN_NAME': 'race', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$13::TEXT', 'FILENAMES': 'admissions.csv.gz', 'ORDER_ID': 12}
# {'COLUMN_NAME': 'edregtime', 'TYPE': 'TIMESTAMP_NTZ', 'NULLABLE': True, 'EXPRESSION': '$14::TIMESTAMP_NTZ', 'FILENAMES': 'admissions.csv.gz', 'ORDER_ID': 13}
# {'COLUMN_NAME': 'edouttime', 'TYPE': 'TIMESTAMP_NTZ', 'NULLABLE': True, 'EXPRESSION': '$15::TIMESTAMP_NTZ', 'FILENAMES': 'admissions.csv.gz', 'ORDER_ID': 14}
# {'COLUMN_NAME': 'hospital_expire_flag', 'TYPE': 'NUMBER(1, 0)', 'NULLABLE': True, 'EXPRESSION': '$16::NUMBER(1, 0)', 'FILENAMES': 'admissions.csv.gz', 'ORDER_ID': 15}
# =================== DDL STATEMENT =====================
# CREATE TABLE IF NOT EXISTS ADMISSIONS_RAW (
#    subject_id NUMBER(8, 0),
#    hadm_id NUMBER(8, 0),
#    admittime TIMESTAMP_NTZ,
#    dischtime TIMESTAMP_NTZ,
#    deathtime TIMESTAMP_NTZ,
#    admission_type TEXT,
#    admit_provider_id TEXT,
#    admission_location TEXT,
#    discharge_location TEXT,
#    insurance TEXT,
#    language TEXT,
#    marital_status TEXT,
#    race TEXT,
#    edregtime TIMESTAMP_NTZ,
#    edouttime TIMESTAMP_NTZ,
#    hospital_expire_flag NUMBER(1, 0))
# =================== copy_stmt =====================
#
#     COPY INTO admissions_raw
#     FROM @my_internal_stage/admissions.csv.gz
#     FILE_FORMAT = (FORMAT_NAME = 'file_format_load')
#     ON_ERROR = 'CONTINUE';
#
# =========================== sql_file_path =============================
# admissions_raw.sql
# ======================================================
#
# Row(name='my_internal_stage/d_icd_diagnoses.csv.gz', size=849392, md5='d77fe5f8249b16ed3692e52bd781dc06', last_modified='Wed, 9 Oct 2024 06:45:17 GMT')
# {'name': 'my_internal_stage/d_icd_diagnoses.csv.gz', 'size': 849392, 'md5': 'd77fe5f8249b16ed3692e52bd781dc06', 'last_modified': 'Wed, 9 Oct 2024 06:45:17 GMT'}
# my_internal_stage/d_icd_diagnoses.csv.gz
# my_internal_stage
# d_icd_diagnoses.csv.gz
# @my_internal_stage
#
# =========== INFER SCHEMA SQL =============
#  d_icd_diagnoses.csv.gz
#
# =========== INFER SCHEMA SQL =============
#         SELECT *
#         FROM TABLE(
#             INFER_SCHEMA(
#             LOCATION=>'@my_internal_stage/',
#             files => 'd_icd_diagnoses.csv.gz',
#             FILE_FORMAT => 'file_format_ddl'
#         )
#     )
#
# [Row(COLUMN_NAME='icd_code', TYPE='TEXT', NULLABLE=True, EXPRESSION='$1::TEXT', FILENAMES='d_icd_diagnoses.csv.gz', ORDER_ID=0), Row(COLUMN_NAME='icd_version', TYPE='NUMBER(2, 0)', NULLABLE=True, EXPRESSION='$2::NUMBER(2, 0)', FILENAMES='d_icd_diagnoses.csv.gz', ORDER_ID=1), Row(COLUMN_NAME='long_title', TYPE='TEXT', NULLABLE=True, EXPRESSION='$3::TEXT', FILENAMES='d_icd_diagnoses.csv.gz', ORDER_ID=2)]
# {'COLUMN_NAME': 'icd_code', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$1::TEXT', 'FILENAMES': 'd_icd_diagnoses.csv.gz', 'ORDER_ID': 0}
# {'COLUMN_NAME': 'icd_version', 'TYPE': 'NUMBER(2, 0)', 'NULLABLE': True, 'EXPRESSION': '$2::NUMBER(2, 0)', 'FILENAMES': 'd_icd_diagnoses.csv.gz', 'ORDER_ID': 1}
# {'COLUMN_NAME': 'long_title', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$3::TEXT', 'FILENAMES': 'd_icd_diagnoses.csv.gz', 'ORDER_ID': 2}
# =================== DDL STATEMENT =====================
# CREATE TABLE IF NOT EXISTS D_ICD_DIAGNOSES_RAW (
#    icd_code TEXT,
#    icd_version NUMBER(2, 0),
#    long_title TEXT)
# =================== copy_stmt =====================
#
#     COPY INTO d_icd_diagnoses_raw
#     FROM @my_internal_stage/d_icd_diagnoses.csv.gz
#     FILE_FORMAT = (FORMAT_NAME = 'file_format_load')
#     ON_ERROR = 'CONTINUE';
#
# =========================== sql_file_path =============================
# d_icd_diagnoses_raw.sql
# ======================================================
#
# Row(name='my_internal_stage/d_icd_procedures.csv.gz', size=549936, md5='d4a9b85d7ee6a75d32f6e1d61ac173cf', last_modified='Wed, 9 Oct 2024 06:44:37 GMT')
# {'name': 'my_internal_stage/d_icd_procedures.csv.gz', 'size': 549936, 'md5': 'd4a9b85d7ee6a75d32f6e1d61ac173cf', 'last_modified': 'Wed, 9 Oct 2024 06:44:37 GMT'}
# my_internal_stage/d_icd_procedures.csv.gz
# my_internal_stage
# d_icd_procedures.csv.gz
# @my_internal_stage
#
# =========== INFER SCHEMA SQL =============
#  d_icd_procedures.csv.gz
#
# =========== INFER SCHEMA SQL =============
#         SELECT *
#         FROM TABLE(
#             INFER_SCHEMA(
#             LOCATION=>'@my_internal_stage/',
#             files => 'd_icd_procedures.csv.gz',
#             FILE_FORMAT => 'file_format_ddl'
#         )
#     )
#
# [Row(COLUMN_NAME='icd_code', TYPE='TEXT', NULLABLE=True, EXPRESSION='$1::TEXT', FILENAMES='d_icd_procedures.csv.gz', ORDER_ID=0), Row(COLUMN_NAME='icd_version', TYPE='NUMBER(2, 0)', NULLABLE=True, EXPRESSION='$2::NUMBER(2, 0)', FILENAMES='d_icd_procedures.csv.gz', ORDER_ID=1), Row(COLUMN_NAME='long_title', TYPE='TEXT', NULLABLE=True, EXPRESSION='$3::TEXT', FILENAMES='d_icd_procedures.csv.gz', ORDER_ID=2)]
# {'COLUMN_NAME': 'icd_code', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$1::TEXT', 'FILENAMES': 'd_icd_procedures.csv.gz', 'ORDER_ID': 0}
# {'COLUMN_NAME': 'icd_version', 'TYPE': 'NUMBER(2, 0)', 'NULLABLE': True, 'EXPRESSION': '$2::NUMBER(2, 0)', 'FILENAMES': 'd_icd_procedures.csv.gz', 'ORDER_ID': 1}
# {'COLUMN_NAME': 'long_title', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$3::TEXT', 'FILENAMES': 'd_icd_procedures.csv.gz', 'ORDER_ID': 2}
# =================== DDL STATEMENT =====================
# CREATE TABLE IF NOT EXISTS D_ICD_PROCEDURES_RAW (
#    icd_code TEXT,
#    icd_version NUMBER(2, 0),
#    long_title TEXT)
# =================== copy_stmt =====================
#
#     COPY INTO d_icd_procedures_raw
#     FROM @my_internal_stage/d_icd_procedures.csv.gz
#     FILE_FORMAT = (FORMAT_NAME = 'file_format_load')
#     ON_ERROR = 'CONTINUE';
#
# =========================== sql_file_path =============================
# d_icd_procedures_raw.sql
# ======================================================
#
# Row(name='my_internal_stage/discharge.csv.gz', size=126310544, md5='e7c7771791f2027cd839f138019523f0', last_modified='Wed, 9 Oct 2024 06:45:12 GMT')
# {'name': 'my_internal_stage/discharge.csv.gz', 'size': 126310544, 'md5': 'e7c7771791f2027cd839f138019523f0', 'last_modified': 'Wed, 9 Oct 2024 06:45:12 GMT'}
# my_internal_stage/discharge.csv.gz
# my_internal_stage
# discharge.csv.gz
# ======================================================
#
# Row(name='my_internal_stage/drgcodes.csv.gz', size=9509520, md5='89a92ba0a394557ceaa16cfcf7c93bce', last_modified='Wed, 9 Oct 2024 06:45:16 GMT')
# {'name': 'my_internal_stage/drgcodes.csv.gz', 'size': 9509520, 'md5': '89a92ba0a394557ceaa16cfcf7c93bce', 'last_modified': 'Wed, 9 Oct 2024 06:45:16 GMT'}
# my_internal_stage/drgcodes.csv.gz
# my_internal_stage
# drgcodes.csv.gz
# @my_internal_stage
#
# =========== INFER SCHEMA SQL =============
#  drgcodes.csv.gz
#
# =========== INFER SCHEMA SQL =============
#         SELECT *
#         FROM TABLE(
#             INFER_SCHEMA(
#             LOCATION=>'@my_internal_stage/',
#             files => 'drgcodes.csv.gz',
#             FILE_FORMAT => 'file_format_ddl'
#         )
#     )
#
# [Row(COLUMN_NAME='subject_id', TYPE='NUMBER(8, 0)', NULLABLE=True, EXPRESSION='$1::NUMBER(8, 0)', FILENAMES='drgcodes.csv.gz', ORDER_ID=0), Row(COLUMN_NAME='hadm_id', TYPE='NUMBER(8, 0)', NULLABLE=True, EXPRESSION='$2::NUMBER(8, 0)', FILENAMES='drgcodes.csv.gz', ORDER_ID=1), Row(COLUMN_NAME='drg_type', TYPE='TEXT', NULLABLE=True, EXPRESSION='$3::TEXT', FILENAMES='drgcodes.csv.gz', ORDER_ID=2), Row(COLUMN_NAME='drg_code', TYPE='NUMBER(3, 0)', NULLABLE=True, EXPRESSION='$4::NUMBER(3, 0)', FILENAMES='drgcodes.csv.gz', ORDER_ID=3), Row(COLUMN_NAME='description', TYPE='TEXT', NULLABLE=True, EXPRESSION='$5::TEXT', FILENAMES='drgcodes.csv.gz', ORDER_ID=4), Row(COLUMN_NAME='drg_severity', TYPE='NUMBER(1, 0)', NULLABLE=True, EXPRESSION='$6::NUMBER(1, 0)', FILENAMES='drgcodes.csv.gz', ORDER_ID=5), Row(COLUMN_NAME='drg_mortality', TYPE='NUMBER(1, 0)', NULLABLE=True, EXPRESSION='$7::NUMBER(1, 0)', FILENAMES='drgcodes.csv.gz', ORDER_ID=6)]
# {'COLUMN_NAME': 'subject_id', 'TYPE': 'NUMBER(8, 0)', 'NULLABLE': True, 'EXPRESSION': '$1::NUMBER(8, 0)', 'FILENAMES': 'drgcodes.csv.gz', 'ORDER_ID': 0}
# {'COLUMN_NAME': 'hadm_id', 'TYPE': 'NUMBER(8, 0)', 'NULLABLE': True, 'EXPRESSION': '$2::NUMBER(8, 0)', 'FILENAMES': 'drgcodes.csv.gz', 'ORDER_ID': 1}
# {'COLUMN_NAME': 'drg_type', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$3::TEXT', 'FILENAMES': 'drgcodes.csv.gz', 'ORDER_ID': 2}
# {'COLUMN_NAME': 'drg_code', 'TYPE': 'NUMBER(3, 0)', 'NULLABLE': True, 'EXPRESSION': '$4::NUMBER(3, 0)', 'FILENAMES': 'drgcodes.csv.gz', 'ORDER_ID': 3}
# {'COLUMN_NAME': 'description', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$5::TEXT', 'FILENAMES': 'drgcodes.csv.gz', 'ORDER_ID': 4}
# {'COLUMN_NAME': 'drg_severity', 'TYPE': 'NUMBER(1, 0)', 'NULLABLE': True, 'EXPRESSION': '$6::NUMBER(1, 0)', 'FILENAMES': 'drgcodes.csv.gz', 'ORDER_ID': 5}
# {'COLUMN_NAME': 'drg_mortality', 'TYPE': 'NUMBER(1, 0)', 'NULLABLE': True, 'EXPRESSION': '$7::NUMBER(1, 0)', 'FILENAMES': 'drgcodes.csv.gz', 'ORDER_ID': 6}
# =================== DDL STATEMENT =====================
# CREATE TABLE IF NOT EXISTS DRGCODES_RAW (
#    subject_id NUMBER(8, 0),
#    hadm_id NUMBER(8, 0),
#    drg_type TEXT,
#    drg_code NUMBER(3, 0),
#    description TEXT,
#    drg_severity NUMBER(1, 0),
#    drg_mortality NUMBER(1, 0))
# =================== copy_stmt =====================
#
#     COPY INTO drgcodes_raw
#     FROM @my_internal_stage/drgcodes.csv.gz
#     FILE_FORMAT = (FORMAT_NAME = 'file_format_load')
#     ON_ERROR = 'CONTINUE';
#
# =========================== sql_file_path =============================
# drgcodes_raw.sql
# ======================================================
#
# Row(name='my_internal_stage/pharmacy.csv.gz', size=490336976, md5='a0750d0989ad0a5251c3ef42463974e8-59', last_modified='Wed, 9 Oct 2024 06:48:38 GMT')
# {'name': 'my_internal_stage/pharmacy.csv.gz', 'size': 490336976, 'md5': 'a0750d0989ad0a5251c3ef42463974e8-59', 'last_modified': 'Wed, 9 Oct 2024 06:48:38 GMT'}
# my_internal_stage/pharmacy.csv.gz
# my_internal_stage
# pharmacy.csv.gz
# 0:00:51.359764

# %% [markdown]
# ---
# discharge load
#
# ---

# %%
def create_file_format(session):
    print("Creating file format for DDL...")
    session.sql("""
        CREATE OR REPLACE FILE FORMAT file_format_ddl
        TYPE = 'CSV'
        COMPRESSION = 'auto'                   -- Specify GZIP compression for .gz files
        FIELD_DELIMITER = ','                   -- Specify the field delimiter
        PARSE_HEADER = TRUE                    -- Parse the header row for column names
        FIELD_OPTIONALLY_ENCLOSED_BY = '\042'
        ESCAPE_UNENCLOSED_FIELD = NONE 
        TRIM_SPACE = TRUE 
        ERROR_ON_COLUMN_COUNT_MISMATCH = FALSE;
    """).collect()

    print("File format 'file_format_ddl' created successfully.")
    print("===========")

    session.sql("""
        CREATE OR REPLACE FILE FORMAT file_format_load
        TYPE = 'CSV'
        COMPRESSION = 'auto'                   -- Specify GZIP compression for .gz files
        FIELD_DELIMITER = ','                   -- Specify the field delimiter
        RECORD_DELIMITER = '\n' 
        SKIP_HEADER = 1                      -- Parse the header row for column names
        FIELD_OPTIONALLY_ENCLOSED_BY = '\042'     -- Optional field enclosure
        ESCAPE_UNENCLOSED_FIELD = None ;
    """).collect()

    print("File format 'file_format_load' created successfully.")
    print("===========")

    session.sql("""
            CREATE OR REPLACE FILE FORMAT file_format_generic
            TYPE = 'CSV'
            COMPRESSION = 'GZIP'                   -- Specify GZIP compression for .gz files
            FIELD_DELIMITER = ','                   -- Specify the field delimiter
            PARSE_HEADER = TRUE                      -- Parse the header row for column names
            FIELD_OPTIONALLY_ENCLOSED_BY = '"'     -- Optional field enclosure
            ESCAPE_UNENCLOSED_FIELD = None;
        """).collect()

    print("File format 'file_format_generic' created successfully.")
    print("===========")

# %%
create_file_format(session_wih_pwd)
# Out:
# Creating file format for DDL...
# File format 'file_format_ddl' created successfully.
# ===========
# File format 'file_format_load' created successfully.
# ===========
# File format 'file_format_generic' created successfully.
# ===========

# %%
for row in stg_files:
    print("======================================================\n")
    print(row)
    row_value = row.as_dict()
    print(row_value)
    stg_file_path_value = row_value.get('name')
    print(stg_file_path_value)

    file_path, file_name = os.path.split(stg_file_path_value)
    print(file_path)
    print(file_name)

    stg_location = "@"+file_path
    print(stg_location)

    if file_name not in ('discharge.csv.gz', 'pharmacy.csv.gz'):
        continue

    
  

    infer_schema_sql = """\
        SELECT * 
        FROM TABLE(
            INFER_SCHEMA(
            LOCATION=>'{}/',
            files => '{}',
            FILE_FORMAT => 'file_format_generic',
            MAX_RECORDS_PER_FILE => 5
        )    
    )
    """.format(stg_location, file_name)

    print(f"\n=========== INFER SCHEMA SQL =============")
    print(f" {file_name}")
    print(f"\n=========== INFER SCHEMA SQL =============")
    print(infer_schema_sql)

    inferred_schema_rows = session_wih_pwd.sql(infer_schema_sql).collect()
    print("\n============== print(inferred_schema_rows)================== \n")
    print(inferred_schema_rows)
    col_name_lst = []
    col_data_type_lst = []

    for row in inferred_schema_rows:
        row_value = row.as_dict()
        print(row_value)
        column_name = row_value.get('COLUMN_NAME')
        column_type = row_value.get('TYPE')

        col_name_lst.append(column_name)
        col_data_type_lst.append(column_type)

    table_name = file_name.split('.')[0]+"_raw"
    create_ddl_stmt = generate_ddl_statement(col_name_lst,col_data_type_lst, table_name.upper())
    print("=================== DDL STATEMENT =====================")
    print(create_ddl_stmt)

    copy_stmt = generate_copy_statement(table_name, 'my_internal_stage', file_name, 'file_format_load')
    print("=================== copy_stmt =====================")
    print(copy_stmt)


    sql_file_path = table_name+".sql"
    print("=========================== sql_file_path =============================")
    print(f"{sql_file_path}")
    with open(sql_file_path, "w") as sql_file:
        sql_file.write("---- Following statement is creating table\n\n")
        sql_file.write(create_ddl_stmt)
        sql_file.write("\n-- Following statement is executing copy command")
        sql_file.write(copy_stmt)

    session_wih_pwd.sql(create_ddl_stmt).collect()
    session_wih_pwd.sql(copy_stmt).collect()
    utc_end_time = datetime.utcnow()

print(utc_end_time-utc_start_time)
# Out:
# ======================================================
#
# Row(name='my_internal_stage/admissions.csv.gz', size=19652448, md5='e030d760b3e15ce1c6aa9e8e8637ebcd', last_modified='Wed, 9 Oct 2024 06:45:27 GMT')
# {'name': 'my_internal_stage/admissions.csv.gz', 'size': 19652448, 'md5': 'e030d760b3e15ce1c6aa9e8e8637ebcd', 'last_modified': 'Wed, 9 Oct 2024 06:45:27 GMT'}
# my_internal_stage/admissions.csv.gz
# my_internal_stage
# admissions.csv.gz
# @my_internal_stage
# ======================================================
#
# Row(name='my_internal_stage/d_icd_diagnoses.csv.gz', size=849392, md5='d77fe5f8249b16ed3692e52bd781dc06', last_modified='Wed, 9 Oct 2024 06:45:17 GMT')
# {'name': 'my_internal_stage/d_icd_diagnoses.csv.gz', 'size': 849392, 'md5': 'd77fe5f8249b16ed3692e52bd781dc06', 'last_modified': 'Wed, 9 Oct 2024 06:45:17 GMT'}
# my_internal_stage/d_icd_diagnoses.csv.gz
# my_internal_stage
# d_icd_diagnoses.csv.gz
# @my_internal_stage
# ======================================================
#
# Row(name='my_internal_stage/d_icd_procedures.csv.gz', size=549936, md5='d4a9b85d7ee6a75d32f6e1d61ac173cf', last_modified='Wed, 9 Oct 2024 06:44:37 GMT')
# {'name': 'my_internal_stage/d_icd_procedures.csv.gz', 'size': 549936, 'md5': 'd4a9b85d7ee6a75d32f6e1d61ac173cf', 'last_modified': 'Wed, 9 Oct 2024 06:44:37 GMT'}
# my_internal_stage/d_icd_procedures.csv.gz
# my_internal_stage
# d_icd_procedures.csv.gz
# @my_internal_stage
# ======================================================
#
# Row(name='my_internal_stage/discharge.csv.gz', size=126310544, md5='e7c7771791f2027cd839f138019523f0', last_modified='Wed, 9 Oct 2024 06:45:12 GMT')
# {'name': 'my_internal_stage/discharge.csv.gz', 'size': 126310544, 'md5': 'e7c7771791f2027cd839f138019523f0', 'last_modified': 'Wed, 9 Oct 2024 06:45:12 GMT'}
# my_internal_stage/discharge.csv.gz
# my_internal_stage
# discharge.csv.gz
# @my_internal_stage
#
# =========== INFER SCHEMA SQL =============
#  discharge.csv.gz
#
# =========== INFER SCHEMA SQL =============
#         SELECT *
#         FROM TABLE(
#             INFER_SCHEMA(
#             LOCATION=>'@my_internal_stage/',
#             files => 'discharge.csv.gz',
#             FILE_FORMAT => 'file_format_generic',
#             MAX_RECORDS_PER_FILE => 5
#         )
#     )
#
#
# ============== print(inferred_schema_rows)==================
#
# [Row(COLUMN_NAME='note_id', TYPE='TEXT', NULLABLE=True, EXPRESSION='$1::TEXT', FILENAMES='discharge.csv.gz', ORDER_ID=0), Row(COLUMN_NAME='subject_id', TYPE='NUMBER(8, 0)', NULLABLE=True, EXPRESSION='$2::NUMBER(8, 0)', FILENAMES='discharge.csv.gz', ORDER_ID=1), Row(COLUMN_NAME='hadm_id', TYPE='NUMBER(8, 0)', NULLABLE=True, EXPRESSION='$3::NUMBER(8, 0)', FILENAMES='discharge.csv.gz', ORDER_ID=2), Row(COLUMN_NAME='note_type', TYPE='TEXT', NULLABLE=True, EXPRESSION='$4::TEXT', FILENAMES='discharge.csv.gz', ORDER_ID=3), Row(COLUMN_NAME='note_seq', TYPE='NUMBER(2, 0)', NULLABLE=True, EXPRESSION='$5::NUMBER(2, 0)', FILENAMES='discharge.csv.gz', ORDER_ID=4), Row(COLUMN_NAME='charttime', TYPE='TIMESTAMP_NTZ', NULLABLE=True, EXPRESSION='$6::TIMESTAMP_NTZ', FILENAMES='discharge.csv.gz', ORDER_ID=5), Row(COLUMN_NAME='storetime', TYPE='TIMESTAMP_NTZ', NULLABLE=True, EXPRESSION='$7::TIMESTAMP_NTZ', FILENAMES='discharge.csv.gz', ORDER_ID=6), Row(COLUMN_NAME='text', TYPE='TEXT', NULLABLE=True, EXPRESSION='$8::TEXT', FILENAMES='discharge.csv.gz', ORDER_ID=7)]
# {'COLUMN_NAME': 'note_id', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$1::TEXT', 'FILENAMES': 'discharge.csv.gz', 'ORDER_ID': 0}
# {'COLUMN_NAME': 'subject_id', 'TYPE': 'NUMBER(8, 0)', 'NULLABLE': True, 'EXPRESSION': '$2::NUMBER(8, 0)', 'FILENAMES': 'discharge.csv.gz', 'ORDER_ID': 1}
# {'COLUMN_NAME': 'hadm_id', 'TYPE': 'NUMBER(8, 0)', 'NULLABLE': True, 'EXPRESSION': '$3::NUMBER(8, 0)', 'FILENAMES': 'discharge.csv.gz', 'ORDER_ID': 2}
# {'COLUMN_NAME': 'note_type', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$4::TEXT', 'FILENAMES': 'discharge.csv.gz', 'ORDER_ID': 3}
# {'COLUMN_NAME': 'note_seq', 'TYPE': 'NUMBER(2, 0)', 'NULLABLE': True, 'EXPRESSION': '$5::NUMBER(2, 0)', 'FILENAMES': 'discharge.csv.gz', 'ORDER_ID': 4}
# {'COLUMN_NAME': 'charttime', 'TYPE': 'TIMESTAMP_NTZ', 'NULLABLE': True, 'EXPRESSION': '$6::TIMESTAMP_NTZ', 'FILENAMES': 'discharge.csv.gz', 'ORDER_ID': 5}
# {'COLUMN_NAME': 'storetime', 'TYPE': 'TIMESTAMP_NTZ', 'NULLABLE': True, 'EXPRESSION': '$7::TIMESTAMP_NTZ', 'FILENAMES': 'discharge.csv.gz', 'ORDER_ID': 6}
# {'COLUMN_NAME': 'text', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$8::TEXT', 'FILENAMES': 'discharge.csv.gz', 'ORDER_ID': 7}
# =================== DDL STATEMENT =====================
# CREATE TABLE IF NOT EXISTS DISCHARGE_RAW (
#    note_id TEXT,
#    subject_id NUMBER(8, 0),
#    hadm_id NUMBER(8, 0),
#    note_type TEXT,
#    note_seq NUMBER(2, 0),
#    charttime TIMESTAMP_NTZ,
#    storetime TIMESTAMP_NTZ,
#    text TEXT)
# =================== copy_stmt =====================
#
#     COPY INTO discharge_raw
#     FROM @my_internal_stage/discharge.csv.gz
#     FILE_FORMAT = (FORMAT_NAME = 'file_format_load')
#     ON_ERROR = 'CONTINUE';
#
# =========================== sql_file_path =============================
# discharge_raw.sql
# ======================================================
#
# Row(name='my_internal_stage/drgcodes.csv.gz', size=9509520, md5='89a92ba0a394557ceaa16cfcf7c93bce', last_modified='Wed, 9 Oct 2024 06:45:16 GMT')
# {'name': 'my_internal_stage/drgcodes.csv.gz', 'size': 9509520, 'md5': '89a92ba0a394557ceaa16cfcf7c93bce', 'last_modified': 'Wed, 9 Oct 2024 06:45:16 GMT'}
# my_internal_stage/drgcodes.csv.gz
# my_internal_stage
# drgcodes.csv.gz
# @my_internal_stage
# ======================================================
#
# Row(name='my_internal_stage/pharmacy.csv.gz', size=490336976, md5='a0750d0989ad0a5251c3ef42463974e8-59', last_modified='Wed, 9 Oct 2024 06:48:38 GMT')
# {'name': 'my_internal_stage/pharmacy.csv.gz', 'size': 490336976, 'md5': 'a0750d0989ad0a5251c3ef42463974e8-59', 'last_modified': 'Wed, 9 Oct 2024 06:48:38 GMT'}
# my_internal_stage/pharmacy.csv.gz
# my_internal_stage
# pharmacy.csv.gz
# @my_internal_stage
#
# =========== INFER SCHEMA SQL =============
#  pharmacy.csv.gz
#
# =========== INFER SCHEMA SQL =============
#         SELECT *
#         FROM TABLE(
#             INFER_SCHEMA(
#             LOCATION=>'@my_internal_stage/',
#             files => 'pharmacy.csv.gz',
#             FILE_FORMAT => 'file_format_generic',
#             MAX_RECORDS_PER_FILE => 5
#         )
#     )
#
#
# ============== print(inferred_schema_rows)==================
#
# [Row(COLUMN_NAME='subject_id', TYPE='NUMBER(8, 0)', NULLABLE=True, EXPRESSION='$1::NUMBER(8, 0)', FILENAMES='pharmacy.csv.gz', ORDER_ID=0), Row(COLUMN_NAME='hadm_id', TYPE='NUMBER(8, 0)', NULLABLE=True, EXPRESSION='$2::NUMBER(8, 0)', FILENAMES='pharmacy.csv.gz', ORDER_ID=1), Row(COLUMN_NAME='pharmacy_id', TYPE='NUMBER(8, 0)', NULLABLE=True, EXPRESSION='$3::NUMBER(8, 0)', FILENAMES='pharmacy.csv.gz', ORDER_ID=2), Row(COLUMN_NAME='poe_id', TYPE='TEXT', NULLABLE=True, EXPRESSION='$4::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=3), Row(COLUMN_NAME='starttime', TYPE='TIMESTAMP_NTZ', NULLABLE=True, EXPRESSION='$5::TIMESTAMP_NTZ', FILENAMES='pharmacy.csv.gz', ORDER_ID=4), Row(COLUMN_NAME='stoptime', TYPE='TIMESTAMP_NTZ', NULLABLE=True, EXPRESSION='$6::TIMESTAMP_NTZ', FILENAMES='pharmacy.csv.gz', ORDER_ID=5), Row(COLUMN_NAME='medication', TYPE='TEXT', NULLABLE=True, EXPRESSION='$7::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=6), Row(COLUMN_NAME='proc_type', TYPE='TEXT', NULLABLE=True, EXPRESSION='$8::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=7), Row(COLUMN_NAME='status', TYPE='TEXT', NULLABLE=True, EXPRESSION='$9::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=8), Row(COLUMN_NAME='entertime', TYPE='TIMESTAMP_NTZ', NULLABLE=True, EXPRESSION='$10::TIMESTAMP_NTZ', FILENAMES='pharmacy.csv.gz', ORDER_ID=9), Row(COLUMN_NAME='verifiedtime', TYPE='TIMESTAMP_NTZ', NULLABLE=True, EXPRESSION='$11::TIMESTAMP_NTZ', FILENAMES='pharmacy.csv.gz', ORDER_ID=10), Row(COLUMN_NAME='route', TYPE='TEXT', NULLABLE=True, EXPRESSION='$12::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=11), Row(COLUMN_NAME='frequency', TYPE='TEXT', NULLABLE=True, EXPRESSION='$13::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=12), Row(COLUMN_NAME='disp_sched', TYPE='TEXT', NULLABLE=True, EXPRESSION='$14::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=13), Row(COLUMN_NAME='infusion_type', TYPE='TEXT', NULLABLE=True, EXPRESSION='$15::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=14), Row(COLUMN_NAME='sliding_scale', TYPE='TEXT', NULLABLE=True, EXPRESSION='$16::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=15), Row(COLUMN_NAME='lockout_interval', TYPE='TEXT', NULLABLE=True, EXPRESSION='$17::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=16), Row(COLUMN_NAME='basal_rate', TYPE='TEXT', NULLABLE=True, EXPRESSION='$18::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=17), Row(COLUMN_NAME='one_hr_max', TYPE='TEXT', NULLABLE=True, EXPRESSION='$19::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=18), Row(COLUMN_NAME='doses_per_24_hrs', TYPE='NUMBER(1, 0)', NULLABLE=True, EXPRESSION='$20::NUMBER(1, 0)', FILENAMES='pharmacy.csv.gz', ORDER_ID=19), Row(COLUMN_NAME='duration', TYPE='NUMBER(1, 0)', NULLABLE=True, EXPRESSION='$21::NUMBER(1, 0)', FILENAMES='pharmacy.csv.gz', ORDER_ID=20), Row(COLUMN_NAME='duration_interval', TYPE='TEXT', NULLABLE=True, EXPRESSION='$22::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=21), Row(COLUMN_NAME='expiration_value', TYPE='NUMBER(2, 0)', NULLABLE=True, EXPRESSION='$23::NUMBER(2, 0)', FILENAMES='pharmacy.csv.gz', ORDER_ID=22), Row(COLUMN_NAME='expiration_unit', TYPE='TEXT', NULLABLE=True, EXPRESSION='$24::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=23), Row(COLUMN_NAME='expirationdate', TYPE='TEXT', NULLABLE=True, EXPRESSION='$25::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=24), Row(COLUMN_NAME='dispensation', TYPE='TEXT', NULLABLE=True, EXPRESSION='$26::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=25), Row(COLUMN_NAME='fill_quantity', TYPE='TEXT', NULLABLE=True, EXPRESSION='$27::TEXT', FILENAMES='pharmacy.csv.gz', ORDER_ID=26)]
# {'COLUMN_NAME': 'subject_id', 'TYPE': 'NUMBER(8, 0)', 'NULLABLE': True, 'EXPRESSION': '$1::NUMBER(8, 0)', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 0}
# {'COLUMN_NAME': 'hadm_id', 'TYPE': 'NUMBER(8, 0)', 'NULLABLE': True, 'EXPRESSION': '$2::NUMBER(8, 0)', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 1}
# {'COLUMN_NAME': 'pharmacy_id', 'TYPE': 'NUMBER(8, 0)', 'NULLABLE': True, 'EXPRESSION': '$3::NUMBER(8, 0)', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 2}
# {'COLUMN_NAME': 'poe_id', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$4::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 3}
# {'COLUMN_NAME': 'starttime', 'TYPE': 'TIMESTAMP_NTZ', 'NULLABLE': True, 'EXPRESSION': '$5::TIMESTAMP_NTZ', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 4}
# {'COLUMN_NAME': 'stoptime', 'TYPE': 'TIMESTAMP_NTZ', 'NULLABLE': True, 'EXPRESSION': '$6::TIMESTAMP_NTZ', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 5}
# {'COLUMN_NAME': 'medication', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$7::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 6}
# {'COLUMN_NAME': 'proc_type', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$8::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 7}
# {'COLUMN_NAME': 'status', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$9::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 8}
# {'COLUMN_NAME': 'entertime', 'TYPE': 'TIMESTAMP_NTZ', 'NULLABLE': True, 'EXPRESSION': '$10::TIMESTAMP_NTZ', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 9}
# {'COLUMN_NAME': 'verifiedtime', 'TYPE': 'TIMESTAMP_NTZ', 'NULLABLE': True, 'EXPRESSION': '$11::TIMESTAMP_NTZ', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 10}
# {'COLUMN_NAME': 'route', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$12::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 11}
# {'COLUMN_NAME': 'frequency', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$13::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 12}
# {'COLUMN_NAME': 'disp_sched', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$14::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 13}
# {'COLUMN_NAME': 'infusion_type', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$15::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 14}
# {'COLUMN_NAME': 'sliding_scale', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$16::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 15}
# {'COLUMN_NAME': 'lockout_interval', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$17::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 16}
# {'COLUMN_NAME': 'basal_rate', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$18::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 17}
# {'COLUMN_NAME': 'one_hr_max', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$19::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 18}
# {'COLUMN_NAME': 'doses_per_24_hrs', 'TYPE': 'NUMBER(1, 0)', 'NULLABLE': True, 'EXPRESSION': '$20::NUMBER(1, 0)', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 19}
# {'COLUMN_NAME': 'duration', 'TYPE': 'NUMBER(1, 0)', 'NULLABLE': True, 'EXPRESSION': '$21::NUMBER(1, 0)', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 20}
# {'COLUMN_NAME': 'duration_interval', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$22::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 21}
# {'COLUMN_NAME': 'expiration_value', 'TYPE': 'NUMBER(2, 0)', 'NULLABLE': True, 'EXPRESSION': '$23::NUMBER(2, 0)', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 22}
# {'COLUMN_NAME': 'expiration_unit', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$24::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 23}
# {'COLUMN_NAME': 'expirationdate', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$25::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 24}
# {'COLUMN_NAME': 'dispensation', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$26::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 25}
# {'COLUMN_NAME': 'fill_quantity', 'TYPE': 'TEXT', 'NULLABLE': True, 'EXPRESSION': '$27::TEXT', 'FILENAMES': 'pharmacy.csv.gz', 'ORDER_ID': 26}
# =================== DDL STATEMENT =====================
# CREATE TABLE IF NOT EXISTS PHARMACY_RAW (
#    subject_id NUMBER(8, 0),
#    hadm_id NUMBER(8, 0),
#    pharmacy_id NUMBER(8, 0),
#    poe_id TEXT,
#    starttime TIMESTAMP_NTZ,
#    stoptime TIMESTAMP_NTZ,
#    medication TEXT,
#    proc_type TEXT,
#    status TEXT,
#    entertime TIMESTAMP_NTZ,
#    verifiedtime TIMESTAMP_NTZ,
#    route TEXT,
#    frequency TEXT,
#    disp_sched TEXT,
#    infusion_type TEXT,
#    sliding_scale TEXT,
#    lockout_interval TEXT,
#    basal_rate TEXT,
#    one_hr_max TEXT,
#    doses_per_24_hrs NUMBER(1, 0),
#    duration NUMBER(1, 0),
#    duration_interval TEXT,
#    expiration_value NUMBER(2, 0),
#    expiration_unit TEXT,
#    expirationdate TEXT,
#    dispensation TEXT,
#    fill_quantity TEXT)
# =================== copy_stmt =====================
#
#     COPY INTO pharmacy_raw
#     FROM @my_internal_stage/pharmacy.csv.gz
#     FILE_FORMAT = (FORMAT_NAME = 'file_format_load')
#     ON_ERROR = 'CONTINUE';
#
# =========================== sql_file_path =============================
# pharmacy_raw.sql
# 0:22:19.969108
