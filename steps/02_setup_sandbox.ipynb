# %%
import snowflake.snowpark as snowpark
from snowflake.snowpark import Session

# %%
# Testing the functions in the notebook
user = 'DOLPHIN'
password = 'Maapaa@1603'  # Avoid hardcoding sensitive information
account = 'URB63596'
database = 'mimic_iv_medi_assist'
schema = 'raw'
warehouse = 'my_warehouse'

# %%
# Internal stage name
STAGE_NAME = 'my_internal_stage'

# %%
# CSV files and their naming conventions
TABLES_TO_LOAD = [
    'admissions.csv.gz',
    'd_icd_diagnoses.csv.gz',
    'd_icd_procedures.csv.gz',
    'discharge.csv.gz',
    'drgcodes.csv.gz',
    'pharmacy.csv.gz',
]

# %%
# Function to establish Snowflake session
def create_session(user, password, account, database, schema):
    connection_parameters = {
        "user": user,
        "password": password,
        "account": account,
        "database": database,
        "schema": schema,
    }
    return Session.builder.configs(connection_parameters).create()

# %%
session = create_session(user, password, account, database, schema)

# %%
print("Ensuring warehouse is active...")
session.sql(f"USE WAREHOUSE {warehouse};").collect()

for file in TABLES_TO_LOAD:
    table_name = f"{file.split('.')[0]}"  # Remove .gz extension
    print(f"Creating table: {table_name} from file: {file}")

    location = f'@{STAGE_NAME}/{file}'  # Reference to internal stage
    print("=================================================================================\n")
    print(f"Loading data into '{table_name}' from {location}...")

    try:
        # Load data into the Snowflake table using the COPY INTO command with ON_ERROR
        session.sql(f"""
            COPY INTO {table_name}
            FROM {location};
        """).collect()

        print(f"Data loaded into table '{table_name}' successfully.")
    except Exception as e:
        print(f"Error loading data into '{table_name}': {e}")
    print("=================================================================================\n")
# Out:
# Ensuring warehouse is active...
# Creating table: admissions from file: admissions.csv.gz
# =================================================================================
#
# Loading data into 'admissions' from @my_internal_stage/admissions.csv.gz...
# Error loading data into 'admissions': (1304): 01b793b4-0003-a868-0000-13e7001151ba: 001757 (42601): SQL compilation error:
# Table 'ADMISSIONS' does not exist
# =================================================================================
#
# Creating table: d_icd_diagnoses from file: d_icd_diagnoses.csv.gz
# =================================================================================
#
# Loading data into 'd_icd_diagnoses' from @my_internal_stage/d_icd_diagnoses.csv.gz...
# Error loading data into 'd_icd_diagnoses': (1304): 01b793b4-0003-a5ad-0000-13e700114666: 001757 (42601): SQL compilation error:
# Table 'D_ICD_DIAGNOSES' does not exist
# =================================================================================
#
# Creating table: d_icd_procedures from file: d_icd_procedures.csv.gz
# =================================================================================
#
# Loading data into 'd_icd_procedures' from @my_internal_stage/d_icd_procedures.csv.gz...
# Error loading data into 'd_icd_procedures': (1304): 01b793b5-0003-a868-0000-13e7001151be: 001757 (42601): SQL compilation error:
# Table 'D_ICD_PROCEDURES' does not exist
# =================================================================================
#
# Creating table: discharge from file: discharge.csv.gz
# =================================================================================
#
# Loading data into 'discharge' from @my_internal_stage/discharge.csv.gz...
# Error loading data into 'discharge': (1304): 01b793b5-0003-a5ad-0000-13e70011466a: 001757 (42601): SQL compilation error:
# Table 'DISCHARGE' does not exist
# =================================================================================
#
# Creating table: drgcodes from file: drgcodes.csv.gz
# =================================================================================
#
# Loading data into 'drgcodes' from @my_internal_stage/drgcodes.csv.gz...
# Error loading data into 'drgcodes': (1304): 01b793b5-0003-a868-0000-13e7001151c2: 001757 (42601): SQL compilation error:
# Table 'DRGCODES' does not exist
# =================================================================================
#
# Creating table: pharmacy from file: pharmacy.csv.gz
# =================================================================================
#
# Loading data into 'pharmacy' from @my_internal_stage/pharmacy.csv.gz...
# Error loading data into 'pharmacy': (1304): 01b793b5-0003-a5ad-0000-13e70011466e: 001757 (42601): SQL compilation error:
# Table 'PHARMACY' does not exist
# =================================================================================

# %%
# Create file format
def create_file_format(session):
    print("Creating file format...")
    session.sql("""
        CREATE OR REPLACE FILE FORMAT file_format_csv
        TYPE = 'CSV'
        COMPRESSION = 'GZIP'
        FIELD_DELIMITER = ','
        PARSE_HEADER = TRUE
        FIELD_OPTIONALLY_ENCLOSED_BY = '"';
    """).collect()
    print("File format 'file_format_csv' created successfully.")
    print("===========")

# %%
# Create table from inferred schema
def create_table(session, table_name, file_path):
    location = f'@{STAGE_NAME}/{file_path}'  # Reference to internal stage
    print(f"Creating table '{table_name}' with inferred schema from {location}...")

    try:
        session.sql(f"""
            CREATE OR REPLACE TABLE {table_name}
            USING TEMPLATE (
                SELECT ARRAY_AGG(OBJECT_CONSTRUCT(*))
                FROM TABLE(
                    INFER_SCHEMA(
                        LOCATION => '{location}',
                        FILE_FORMAT => 'file_format_csv';
                       
                    )
                )
            );
        """).collect()

        print(f"Table '{table_name}' created successfully with inferred schema.")
    except Exception as e:
        print(f"Error creating table '{table_name}': {e}")
    print("===========\n\n")

# %%
# Load all raw tables
def load_all_raw_tables(session):
    print("Ensuring warehouse is active...")
    session.sql(f"USE WAREHOUSE 'my_warehouse';").collect()

    for file in TABLES_TO_LOAD:
        table_name = f"{file.split('.')[0]}"  # Remove .gz extension
        print(f"Creating table: {table_name} from file: {file}")
        create_table(session, table_name, file)

    print("All tables created successfully.")

# %%
# Create file format and load raw tables
create_file_format(session)
load_all_raw_tables(session)

# %% [markdown]
# ---
# AUTOMATE TEST SCRIPT
#
# ---

# %%
from snowflake.snowpark import Session
import os
from datetime import datetime

# %%
user = 'DOLPHIN'
password = 'Maapaa@1603'  # Avoid hardcoding sensitive information
account = 'URB63596'
database = 'mimic_iv_medi_assist'
schema = 'raw'
warehouse = 'my_warehouse'

# %%
def snowpark_basic_auth() -> Session:
    connection_parameters = {
        "ACCOUNT":"URB63596",
        "USER":"DOLPHIN",
        "PASSWORD":"Maapaa@1603"
    }
    return Session.builder.configs(connection_parameters).create()

# %%
def generate_ddl_statement(column_names, data_types, table_name):
    ddl_template = "CREATE TABLE IF NOT EXISTS {} (\n{})"
    columns = []
    for name, data_type in zip(column_names, data_types):
        column_definition = f"   {name} {data_type}"
        columns.append(column_definition)

    ddl_statement = ddl_template.format(table_name, ",\n".join(columns))
    return ddl_statement

# %%
def generate_copy_statement(table_name,stage_name,csv_file_path,file_format):
    copy_command = f"""
    COPY INTO {table_name}
    FROM @{stage_name}/{csv_file_path}
    FILE_FORMAT = (FORMAT_NAME = '{file_format}')
    ;
    """

    return copy_command

# %%
def create_file_format(session):
    print("Creating file format...")
    session.sql("""
        CREATE OR REPLACE FILE FORMAT file_format_csv
        TYPE = 'CSV'
        COMPRESSION = 'GZIP'                   -- Specify GZIP compression for .gz files
        FIELD_DELIMITER = ','                   -- Specify the field delimiter
        PARSE_HEADER = TRUE                      -- Parse the header row for column names
        FIELD_OPTIONALLY_ENCLOSED_BY = '"';     -- Optional field enclosure
    """).collect()

    print("File format 'file_format_csv' created successfully.")
    print("===========")

# %%
def create_file_format(session):
    print("Creating file format for DDL...")
    session.sql("""
        CREATE OR REPLACE FILE FORMAT file_format_ddl
        TYPE = 'CSV'
        COMPRESSION = 'auto'                   -- Specify GZIP compression for .gz files
        FIELD_DELIMITER = ','                   -- Specify the field delimiter
        PARSE_HEADER = TRUE                    -- Parse the header row for column names
        FIELD_OPTIONALLY_ENCLOSED_BY = '\042'
        ESCAPE_UNENCLOSED_FIELD = NONE 
        TRIM_SPACE = TRUE 
        ERROR_ON_COLUMN_COUNT_MISMATCH = FALSE;
    """).collect()

    print("File format 'file_format_ddl' created successfully.")
    print("===========")

    session.sql("""
        CREATE OR REPLACE FILE FORMAT file_format_load
        TYPE = 'CSV'
        COMPRESSION = 'auto'                   -- Specify GZIP compression for .gz files
        FIELD_DELIMITER = ','                   -- Specify the field delimiter
        RECORD_DELIMITER = '\n' 
        SKIP_HEADER = 1                      -- Parse the header row for column names
        FIELD_OPTIONALLY_ENCLOSED_BY = '\042'     -- Optional field enclosure
        ;
    """).collect()

    print("File format 'file_format_load' created successfully.")
    print("===========")

# %%
utc_start_time = datetime.utcnow()
session_wih_pwd = snowpark_basic_auth()


session_wih_pwd.sql("USE DATABASE mimic_iv_medi_assist").collect()
session_wih_pwd.sql("USE SCHEMA raw").collect()
session_wih_pwd.sql("USE WAREHOUSE my_warehouse").collect()

create_file_format(session_wih_pwd)
# Out:
# Creating file format for DDL...
# File format 'file_format_ddl' created successfully.
# ===========
# File format 'file_format_load' created successfully.
# ===========

# %%
stg_files = session_wih_pwd.sql("list @my_internal_stage").collect()
print(stg_files)
# Out:
# [Row(name='my_internal_stage/admissions.csv.gz', size=19652448, md5='e030d760b3e15ce1c6aa9e8e8637ebcd', last_modified='Wed, 9 Oct 2024 06:45:27 GMT'), Row(name='my_internal_stage/d_icd_diagnoses.csv.gz', size=849392, md5='d77fe5f8249b16ed3692e52bd781dc06', last_modified='Wed, 9 Oct 2024 06:45:17 GMT'), Row(name='my_internal_stage/d_icd_procedures.csv.gz', size=549936, md5='d4a9b85d7ee6a75d32f6e1d61ac173cf', last_modified='Wed, 9 Oct 2024 06:44:37 GMT'), Row(name='my_internal_stage/discharge_two.csv.gz', size=1138715888, md5='b85ea55aef83c331f7c821e2e425f0de-136', last_modified='Sat, 12 Oct 2024 04:05:15 GMT'), Row(name='my_internal_stage/drgcodes.csv.gz', size=9509520, md5='89a92ba0a394557ceaa16cfcf7c93bce', last_modified='Wed, 9 Oct 2024 06:45:16 GMT'), Row(name='my_internal_stage/pharmacy.csv.gz', size=28197696, md5='880636d6f06cccdcb30a3b541320f35b', last_modified='Tue, 5 Nov 2024 20:32:14 GMT')]

# %%
for row in stg_files:
    print("======================================================\n")
    print(row)
    row_value = row.as_dict()
    print(row_value)
    stg_file_path_value = row_value.get('name')
    print(stg_file_path_value)

    file_path, file_name = os.path.split(stg_file_path_value)
    print(file_path)
    print(file_name)
    if file_name == 'discharge.csv.gz' or file_name == 'pharmacy.csv.gz':
        continue
    
    stg_location = "@"+file_path
    print(stg_location)

    infer_schema_sql = """\
        SELECT * 
        FROM TABLE(
            INFER_SCHEMA(
            LOCATION=>'{}/',
            files => '{}',
            FILE_FORMAT => 'file_format_ddl'
        )    
    )
    """.format(stg_location, file_name)

    print(f"\n=========== INFER SCHEMA SQL =============")
    print(f" {file_name}")
    print(f"\n=========== INFER SCHEMA SQL =============")
    print(infer_schema_sql)

    inferred_schema_rows = session_wih_pwd.sql(infer_schema_sql).collect()
    print(inferred_schema_rows)
    col_name_lst = []
    col_data_type_lst = []

    for row in inferred_schema_rows:
        row_value = row.as_dict()
        print(row_value)
        column_name = row_value.get('COLUMN_NAME')
        column_type = row_value.get('TYPE')

        col_name_lst.append(column_name)
        col_data_type_lst.append(column_type)

    table_name = file_name.split('.')[0]+"_raw"
    create_ddl_stmt = generate_ddl_statement(col_name_lst,col_data_type_lst, table_name.upper())
    print("=================== DDL STATEMENT =====================")
    print(create_ddl_stmt)

    copy_stmt = generate_copy_statement(table_name, 'my_internal_stage', file_name, 'file_format_load')
    print("=================== copy_stmt =====================")
    print(copy_stmt)


    sql_file_path = table_name+".sql"
    print("=========================== sql_file_path =============================")
    print(f"{sql_file_path}")
    with open(sql_file_path, "w") as sql_file:
        sql_file.write("---- Following statement is creating table\n\n")
        sql_file.write(create_ddl_stmt)
        sql_file.write("\n-- Following statement is executing copy command")
        sql_file.write(copy_stmt)

    session_wih_pwd.sql(create_ddl_stmt).collect()
    session_wih_pwd.sql(copy_stmt).collect()
    utc_end_time = datetime.utcnow()

print(utc_end_time-utc_start_time)
# Out:
# ======================================================
#
# Row(name='my_internal_stage/admissions.csv.gz', size=19652448, md5='e030d760b3e15ce1c6aa9e8e8637ebcd', last_modified='Wed, 9 Oct 2024 06:45:27 GMT')
# {'name': 'my_internal_stage/admissions.csv.gz', 'size': 19652448, 'md5': 'e030d760b3e15ce1c6aa9e8e8637ebcd', 'last_modified': 'Wed, 9 Oct 2024 06:45:27 GMT'}
# my_internal_stage/admissions.csv.gz
# my_internal_stage
# admissions.csv.gz
# @my_internal_stage
#
# =========== INFER SCHEMA SQL =============
#  admissions.csv.gz
#
# =========== INFER SCHEMA SQL =============
#         SELECT *
#         FROM TABLE(
#             INFER_SCHEMA(
#             LOCATION=>'@my_internal_stage/',
#             files => 'admissions.csv.gz',
#             FILE_FORMAT => 'file_format_ddl'
#         )
#     )
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 34
#      31 print(f"\n=========== INFER SCHEMA SQL =============")
#      32 print(infer_schema_sql)
# ---> 34 inferred_schema_rows = session_wih_pwd.sql(infer_schema_sql).collect()
#      35 print(inferred_schema_rows)
#      36 col_name_lst = []
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/telemetry.py:156, in df_collect_api_telemetry.<locals>.wrap(*args, **kwargs)
#     153 @functools.wraps(func)
#     154 def wrap(*args, **kwargs):
#     155     with args[0]._session.query_history() as query_history:
# --> 156         result = func(*args, **kwargs)
#     157     plan = args[0]._select_statement or args[0]._plan
#     158     api_calls = [
#     159         *plan.api_calls,
#     160         {TelemetryField.NAME.value: f"DataFrame.{func.__name__}"},
#     161     ]
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/dataframe.py:603, in DataFrame.collect(self, statement_params, block, log_on_exception, case_sensitive)
#     588 """Executes the query representing this DataFrame and returns the result as a
#     589 list of :class:`Row` objects.
#     590
#    (...)
#     600     :meth:`collect_nowait()`
#     601 """
#     602 with open_telemetry_context_manager(self.collect, self):
# --> 603     return self._internal_collect_with_tag_no_telemetry(
#     604         statement_params=statement_params,
#     605         block=block,
#     606         log_on_exception=log_on_exception,
#     607         case_sensitive=case_sensitive,
#     608     )
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/dataframe.py:651, in DataFrame._internal_collect_with_tag_no_telemetry(self, statement_params, block, data_type, log_on_exception, case_sensitive)
#     639 def _internal_collect_with_tag_no_telemetry(
#     640     self,
#     641     *,
#    (...)
#     649     # we should always call this method instead of collect(), to make sure the
#     650     # query tag is set properly.
# --> 651     return self._session._conn.execute(
#     652         self._plan,
#     653         block=block,
#     654         data_type=data_type,
#     655         _statement_params=create_or_update_statement_params_with_query_tag(
#     656             statement_params or self._statement_params,
#     657             self._session.query_tag,
#     658             SKIP_LEVELS_THREE,
#     659         ),
#     660         log_on_exception=log_on_exception,
#     661         case_sensitive=case_sensitive,
#     662     )
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/server_connection.py:526, in ServerConnection.execute(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     516 if (
#     517     is_in_stored_procedure()
#     518     and not block
#    (...)
#     521     )
#     522 ):  # pragma: no cover
#     523     raise NotImplementedError(
#     524         "Async query is not supported in stored procedure yet"
#     525     )
# --> 526 result_set, result_meta = self.get_result_set(
#     527     plan,
#     528     to_pandas,
#     529     to_iter,
#     530     **kwargs,
#     531     block=block,
#     532     data_type=data_type,
#     533     log_on_exception=log_on_exception,
#     534     case_sensitive=case_sensitive,
#     535 )
#     536 if not block:
#     537     return result_set
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:138, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     136 def wrap(*args, **kwargs):
#     137     try:
# --> 138         return func(*args, **kwargs)
#     139     except snowflake.connector.errors.ProgrammingError as e:
#     140         query = getattr(e, "query", None)
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/server_connection.py:633, in ServerConnection.get_result_set(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, ignore_results, **kwargs)
#     631 for holder, id_ in placeholders.items():
#     632     final_query = final_query.replace(holder, id_)
# --> 633 result = self.run_query(
#     634     final_query,
#     635     to_pandas,
#     636     to_iter and (i == len(main_queries) - 1),
#     637     is_ddl_on_temp_object=query.is_ddl_on_temp_object,
#     638     block=not is_last,
#     639     data_type=data_type,
#     640     async_job_plan=plan,
#     641     log_on_exception=log_on_exception,
#     642     case_sensitive=case_sensitive,
#     643     params=query.params,
#     644     ignore_results=ignore_results,
#     645     **kwargs,
#     646 )
#     647 placeholders[query.query_id_place_holder] = (
#     648     result["sfqid"] if not is_last else result.query_id
#     649 )
#     650 result_meta = get_new_description(self._cursor)
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/server_connection.py:119, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     117     raise SnowparkClientExceptionMessages.SERVER_SESSION_HAS_BEEN_CLOSED()
#     118 try:
# --> 119     return func(*args, **kwargs)
#     120 except ReauthenticationRequest as ex:
#     121     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     122         ex.cause
#     123     )
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/server_connection.py:418, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, ignore_results, **kwargs)
#     416     kwargs["_statement_params"]["SNOWPARK_SKIP_TXN_COMMIT_IN_DDL"] = True
#     417 if block:
# --> 418     results_cursor = self.execute_and_notify_query_listener(
#     419         query, params=params, **kwargs
#     420     )
#     421     logger.debug(f"Execute query [queryID: {results_cursor.sfqid}] {query}")
#     422 else:
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/server_connection.py:369, in ServerConnection.execute_and_notify_query_listener(self, query, **kwargs)
#     366 def execute_and_notify_query_listener(
#     367     self, query: str, **kwargs: Any
#     368 ) -> SnowflakeCursor:
# --> 369     results_cursor = self._cursor.execute(query, **kwargs)
#     370     self.notify_query_listeners(
#     371         QueryRecord(results_cursor.sfqid, results_cursor.query)
#     372     )
#     373     return results_cursor
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/cursor.py:984, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _dataframe_ast)
#     977     logger.debug(
#     978         "query was rewritten: org=%s, new=%s",
#     979         " ".join(line.strip() for line in query.split("\n")),
#     980         query1,
#     981     )
#     982     query = query1
# --> 984 ret = self._execute_helper(query, **kwargs)
#     985 self._sfqid = (
#     986     ret["data"]["queryId"]
#     987     if "data" in ret and "queryId" in ret["data"]
#     988     else None
#     989 )
#     990 logger.debug(f"sfqid: {self.sfqid}")
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/cursor.py:695, in SnowflakeCursor._execute_helper(self, query, timeout, statement_params, binding_params, binding_stage, is_internal, describe_only, _no_results, _is_put_get, _no_retry, dataframe_ast)
#     693 ret: dict[str, Any] = {"data": {}}
#     694 try:
# --> 695     ret = self._connection.cmd_query(
#     696         query,
#     697         self._sequence_counter,
#     698         self._request_id,
#     699         binding_params=binding_params,
#     700         binding_stage=binding_stage,
#     701         is_file_transfer=bool(self._is_file_transfer),
#     702         statement_params=statement_params,
#     703         is_internal=is_internal,
#     704         describe_only=describe_only,
#     705         _no_results=_no_results,
#     706         _no_retry=_no_retry,
#     707         timeout=real_timeout,
#     708         dataframe_ast=dataframe_ast,
#     709     )
#     710 finally:
#     711     try:
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/connection.py:1350, in SnowflakeConnection.cmd_query(self, sql, sequence_counter, request_id, binding_params, binding_stage, is_file_transfer, statement_params, is_internal, describe_only, _no_results, _update_current_object, _no_retry, timeout, dataframe_ast)
#    1341     logger.debug(
#    1342         "sql=[%s], sequence_id=[%s], is_file_transfer=[%s]",
#    1343         self._format_query_for_log(data["sqlText"]),
#    1344         data["sequenceId"],
#    1345         is_file_transfer,
#    1346     )
#    1348 url_parameters = {REQUEST_ID: request_id}
# -> 1350 ret = self.rest.request(
#    1351     "/queries/v1/query-request?" + urlencode(url_parameters),
#    1352     data,
#    1353     client=client,
#    1354     _no_results=_no_results,
#    1355     _include_retry_params=True,
#    1356     _no_retry=_no_retry,
#    1357     timeout=timeout,
#    1358 )
#    1360 if ret is None:
#    1361     ret = {"data": {}}
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/network.py:491, in SnowflakeRestful.request(self, url, body, method, client, timeout, _no_results, _include_retry_params, _no_retry)
#     489     headers[HTTP_HEADER_SERVICE_NAME] = self._connection.service_name
#     490 if method == "post":
# --> 491     return self._post_request(
#     492         url,
#     493         headers,
#     494         json.dumps(body),
#     495         token=self.token,
#     496         _no_results=_no_results,
#     497         timeout=timeout,
#     498         _include_retry_params=_include_retry_params,
#     499         no_retry=_no_retry,
#     500     )
#     501 else:
#     502     return self._get_request(
#     503         url,
#     504         headers,
#     505         token=self.token,
#     506         timeout=timeout,
#     507     )
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/network.py:739, in SnowflakeRestful._post_request(self, url, headers, body, token, timeout, socket_timeout, _no_results, no_retry, _include_retry_params)
#     736     ret = probe_connection(full_url)
#     737     pprint(ret)
# --> 739 ret = self.fetch(
#     740     "post",
#     741     full_url,
#     742     headers,
#     743     data=body,
#     744     timeout=timeout,
#     745     token=token,
#     746     no_retry=no_retry,
#     747     _include_retry_params=_include_retry_params,
#     748     socket_timeout=socket_timeout,
#     749 )
#     750 logger.debug(
#     751     "ret[code] = {code}, after post request".format(
#     752         code=(ret.get("code", "N/A"))
#     753     )
#     754 )
#     756 if ret.get("code") == MASTER_TOKEN_EXPIRED_GS_CODE:
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/network.py:854, in SnowflakeRestful.fetch(self, method, full_url, headers, data, timeout, **kwargs)
#     852 retry_ctx.set_start_time()
#     853 while True:
# --> 854     ret = self._request_exec_wrapper(
#     855         session, method, full_url, headers, data, retry_ctx, **kwargs
#     856     )
#     857     if ret is not None:
#     858         return ret
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/network.py:904, in SnowflakeRestful._request_exec_wrapper(self, session, method, full_url, headers, data, retry_ctx, no_retry, token, **kwargs)
#     902 raise_raw_http_failure = kwargs.pop("raise_raw_http_failure", False)
#     903 try:
# --> 904     return_object = self._request_exec(
#     905         session=session,
#     906         method=method,
#     907         full_url=full_url,
#     908         headers=headers,
#     909         data=data,
#     910         token=token,
#     911         raise_raw_http_failure=raise_raw_http_failure,
#     912         **kwargs,
#     913     )
#     914     if return_object is not None:
#     915         return return_object
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/network.py:1071, in SnowflakeRestful._request_exec(self, session, method, full_url, headers, data, token, catch_okta_unauthorized_error, is_raw_text, is_raw_binary, binary_data_handler, socket_timeout, is_okta_authentication, raise_raw_http_failure)
#    1067 download_start_time = get_time_millis()
#    1068 # socket timeout is constant. You should be able to receive
#    1069 # the response within the time. If not, ConnectReadTimeout or
#    1070 # ReadTimeout is raised.
# -> 1071 raw_ret = session.request(
#    1072     method=method,
#    1073     url=full_url,
#    1074     headers=headers,
#    1075     data=input_data,
#    1076     timeout=socket_timeout,
#    1077     verify=True,
#    1078     stream=is_raw_binary,
#    1079     auth=SnowflakeAuth(token),
#    1080 )
#    1081 download_end_time = get_time_millis()
#    1083 try:
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/vendored/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/vendored/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/vendored/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File /usr/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File /usr/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /usr/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /usr/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/contrib/pyopenssl.py:330, in WrappedSocket.recv_into(self, *args, **kwargs)
#     328         raise
#     329 except OpenSSL.SSL.WantReadError:
# --> 330     if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     331         raise timeout("The read operation timed out")
#     332     else:
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:145, in wait_for_read(sock, timeout)
#     141 def wait_for_read(sock, timeout=None):
#     142     """Waits for reading to be available on a given socket.
#     143     Returns True if the socket is readable, or False if the timeout expired.
#     144     """
# --> 145     return wait_for_socket(sock, read=True, timeout=timeout)
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:106, in poll_wait_for_socket(sock, read, write, timeout)
#     103         t *= 1000
#     104     return poll_obj.poll(t)
# --> 106 return bool(_retry_on_intr(do_poll, timeout))
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:43, in _retry_on_intr(fn, timeout)
#      42 def _retry_on_intr(fn, timeout):
# ---> 43     return fn(timeout)
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/vendored/urllib3/util/wait.py:104, in poll_wait_for_socket.<locals>.do_poll(t)
#     102 if t is not None:
#     103     t *= 1000
# --> 104 return poll_obj.poll(t)
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/cursor.py:684, in SnowflakeCursor._execute_helper.<locals>.interrupt_handler(*_)
#     681         except (ValueError, TypeError):
#     682             # ignore failures
#     683             pass
# --> 684 raise KeyboardInterrupt
#
# KeyboardInterrupt:

# %% [markdown]
# ---
# discharge load
#
# ---

# %%
def create_file_format(session):
    print("Creating file format for DDL...")
    session.sql("""
        CREATE OR REPLACE FILE FORMAT file_format_ddl
        TYPE = 'CSV'
        COMPRESSION = 'auto'                   -- Specify GZIP compression for .gz files
        FIELD_DELIMITER = ','                   -- Specify the field delimiter
        PARSE_HEADER = TRUE                    -- Parse the header row for column names
        FIELD_OPTIONALLY_ENCLOSED_BY = '\042'
        ESCAPE_UNENCLOSED_FIELD = NONE 
        TRIM_SPACE = TRUE 
        ERROR_ON_COLUMN_COUNT_MISMATCH = FALSE;
    """).collect()

    print("File format 'file_format_ddl' created successfully.")
    print("===========")

    session.sql("""
        CREATE OR REPLACE FILE FORMAT file_format_load
        TYPE = 'CSV'
        COMPRESSION = 'auto'                   -- Specify GZIP compression for .gz files
        FIELD_DELIMITER = ','                   -- Specify the field delimiter
        RECORD_DELIMITER = '\n' 
        SKIP_HEADER = 1                      -- Parse the header row for column names
        FIELD_OPTIONALLY_ENCLOSED_BY = '"'    -- Optional field enclosure
         ;
    """).collect()

    print("File format 'file_format_load' created successfully.")
    print("===========")

    session.sql("""
            CREATE OR REPLACE FILE FORMAT file_format_generic
            TYPE = 'CSV'
            COMPRESSION = 'GZIP'                   -- Specify GZIP compression for .gz files
            FIELD_DELIMITER = ','                   -- Specify the field delimiter
            PARSE_HEADER = TRUE                      -- Parse the header row for column names
            FIELD_OPTIONALLY_ENCLOSED_BY = '"'     -- Optional field enclosure
            ESCAPE_UNENCLOSED_FIELD = None;
        """).collect()

    print("File format 'file_format_generic' created successfully.")
    print("===========")

# %%
create_file_format(session_wih_pwd)
# Out:
# Creating file format for DDL...
# File format 'file_format_ddl' created successfully.
# ===========
# File format 'file_format_load' created successfully.
# ===========
# File format 'file_format_generic' created successfully.
# ===========

# %%
import os
from datetime import datetime

utc_start_time = datetime.utcnow()
print("Process started at:", utc_start_time)

for row in stg_files:
    print("======================================================\n")
    print("Processing row:", row)
    
    # Convert row to dictionary
    row_value = row.as_dict()
    print("Row as dictionary:", row_value)
    
    # Extract the staged file path value
    stg_file_path_value = row_value.get('name')
    print("Staged file path value:", stg_file_path_value)

    # Split file path and name
    file_path, file_name = os.path.split(stg_file_path_value)
    print("File path:", file_path)
    print("File name:", file_name)

    # Create staged location variable
    stg_location = "@" + file_path
    print("Staged location:", stg_location)

    # Filter for specific file
    if file_name not in ('pharmacy_two.csv.gz'):
        print(f"Skipping file {file_name} as it doesn't match the target file.")
        continue
    
    print(f"Processing target file: {file_name}")
    
    # Generate SQL for inferring schema
    infer_schema_sql = """\
        SELECT * 
        FROM TABLE(
            INFER_SCHEMA(
            LOCATION=>'{}/',
            files => '{}',
            FILE_FORMAT => 'file_format_generic'
        )    
    )
    """.format(stg_location, file_name)
    
    print("\n=========== INFER SCHEMA SQL =============")
    print(f"File: {file_name}")
    print(infer_schema_sql)

    # Execute schema inference
    inferred_schema_rows = session_wih_pwd.sql(infer_schema_sql).collect()
    print("\nSchema inference completed. Inferred schema rows:")
    print(inferred_schema_rows)

    # Prepare lists for column names and types
    col_name_lst = []
    col_data_type_lst = []

    # Process each row in inferred schema
    for row in inferred_schema_rows:
        row_value = row.as_dict()
        print("Inferred schema row:", row_value)
        
        column_name = row_value.get('COLUMN_NAME')
        column_type = row_value.get('TYPE')

        col_name_lst.append(column_name)
        col_data_type_lst.append(column_type)

    print("Column names list:", col_name_lst)
    print("Column data types list:", col_data_type_lst)

    # Generate table name and DDL statement
    table_name = file_name.split('.')[0] + "_raw"
    create_ddl_stmt = generate_ddl_statement(col_name_lst, col_data_type_lst, table_name.upper())
    print("=================== DDL STATEMENT =====================")
    print(create_ddl_stmt)

    # Generate copy statement for loading data
    copy_stmt = generate_copy_statement(table_name, 'my_internal_stage', file_name, 'file_format_load')
    print("=================== COPY STATEMENT =====================")
    print(copy_stmt)

    # Define SQL file path and save DDL and copy statements to file
    sql_file_path = table_name + ".sql"
    print("=================== SQL FILE PATH =====================")
    print("File path for saving SQL:", sql_file_path)
    with open(sql_file_path, "w") as sql_file:
        sql_file.write("---- Following statement is creating table\n\n")
        sql_file.write(create_ddl_stmt)
        sql_file.write("\n-- Following statement is executing copy command\n")
        sql_file.write(copy_stmt)
    print("SQL statements written to file:", sql_file_path)

    # Execute DDL to create the table
    session_wih_pwd.sql(create_ddl_stmt).collect()
    print("Table created successfully with DDL statement.")

    # Execute copy command to load data into the table
    session_wih_pwd.sql(copy_stmt).collect()
    print("Data loaded into the table with COPY statement.")

# End of processing and time calculation
utc_end_time = datetime.utcnow()
print("Process completed at:", utc_end_time)
print("Total processing time:", utc_end_time - utc_start_time)
# Out:
# Process started at: 2024-11-05 21:27:10.315793
# ======================================================
#
# Processing row: Row(name='my_internal_stage/admissions.csv.gz', size=19652448, md5='e030d760b3e15ce1c6aa9e8e8637ebcd', last_modified='Wed, 9 Oct 2024 06:45:27 GMT')
# Row as dictionary: {'name': 'my_internal_stage/admissions.csv.gz', 'size': 19652448, 'md5': 'e030d760b3e15ce1c6aa9e8e8637ebcd', 'last_modified': 'Wed, 9 Oct 2024 06:45:27 GMT'}
# Staged file path value: my_internal_stage/admissions.csv.gz
# File path: my_internal_stage
# File name: admissions.csv.gz
# Staged location: @my_internal_stage
# Skipping file admissions.csv.gz as it doesn't match the target file.
# ======================================================
#
# Processing row: Row(name='my_internal_stage/d_icd_diagnoses.csv.gz', size=849392, md5='d77fe5f8249b16ed3692e52bd781dc06', last_modified='Wed, 9 Oct 2024 06:45:17 GMT')
# Row as dictionary: {'name': 'my_internal_stage/d_icd_diagnoses.csv.gz', 'size': 849392, 'md5': 'd77fe5f8249b16ed3692e52bd781dc06', 'last_modified': 'Wed, 9 Oct 2024 06:45:17 GMT'}
# Staged file path value: my_internal_stage/d_icd_diagnoses.csv.gz
# File path: my_internal_stage
# File name: d_icd_diagnoses.csv.gz
# Staged location: @my_internal_stage
# Skipping file d_icd_diagnoses.csv.gz as it doesn't match the target file.
# ======================================================
#
# Processing row: Row(name='my_internal_stage/d_icd_procedures.csv.gz', size=549936, md5='d4a9b85d7ee6a75d32f6e1d61ac173cf', last_modified='Wed, 9 Oct 2024 06:44:37 GMT')
# Row as dictionary: {'name': 'my_internal_stage/d_icd_procedures.csv.gz', 'size': 549936, 'md5': 'd4a9b85d7ee6a75d32f6e1d61ac173cf', 'last_modified': 'Wed, 9 Oct 2024 06:44:37 GMT'}
# Staged file path value: my_internal_stage/d_icd_procedures.csv.gz
# File path: my_internal_stage
# File name: d_icd_procedures.csv.gz
# Staged location: @my_internal_stage
# Skipping file d_icd_procedures.csv.gz as it doesn't match the target file.
# ======================================================
#
# Processing row: Row(name='my_internal_stage/discharge_two.csv.gz', size=1138715888, md5='b85ea55aef83c331f7c821e2e425f0de-136', last_modified='Sat, 12 Oct 2024 04:05:15 GMT')
# Row as dictionary: {'name': 'my_internal_stage/discharge_two.csv.gz', 'size': 1138715888, 'md5': 'b85ea55aef83c331f7c821e2e425f0de-136', 'last_modified': 'Sat, 12 Oct 2024 04:05:15 GMT'}
# Staged file path value: my_internal_stage/discharge_two.csv.gz
# File path: my_internal_stage
# File name: discharge_two.csv.gz
# Staged location: @my_internal_stage
# Skipping file discharge_two.csv.gz as it doesn't match the target file.
# ======================================================
#
# Processing row: Row(name='my_internal_stage/drgcodes.csv.gz', size=9509520, md5='89a92ba0a394557ceaa16cfcf7c93bce', last_modified='Wed, 9 Oct 2024 06:45:16 GMT')
# Row as dictionary: {'name': 'my_internal_stage/drgcodes.csv.gz', 'size': 9509520, 'md5': '89a92ba0a394557ceaa16cfcf7c93bce', 'last_modified': 'Wed, 9 Oct 2024 06:45:16 GMT'}
# Staged file path value: my_internal_stage/drgcodes.csv.gz
# File path: my_internal_stage
# File name: drgcodes.csv.gz
# Staged location: @my_internal_stage
# Skipping file drgcodes.csv.gz as it doesn't match the target file.
# ======================================================
#
# Processing row: Row(name='my_internal_stage/pharmacy.csv.gz', size=28197696, md5='880636d6f06cccdcb30a3b541320f35b', last_modified='Tue, 5 Nov 2024 20:32:14 GMT')
# Row as dictionary: {'name': 'my_internal_stage/pharmacy.csv.gz', 'size': 28197696, 'md5': '880636d6f06cccdcb30a3b541320f35b', 'last_modified': 'Tue, 5 Nov 2024 20:32:14 GMT'}
# Staged file path value: my_internal_stage/pharmacy.csv.gz
# File path: my_internal_stage
# File name: pharmacy.csv.gz
# Staged location: @my_internal_stage
# Processing target file: pharmacy.csv.gz
#
# =========== INFER SCHEMA SQL =============
# File: pharmacy.csv.gz
#         SELECT *
#         FROM TABLE(
#             INFER_SCHEMA(
#             LOCATION=>'@my_internal_stage/',
#             files => 'pharmacy.csv.gz',
#             FILE_FORMAT => 'file_format_generic'
#         )
#     )
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[21], line 52
#      49 print(infer_schema_sql)
#      51 # Execute schema inference
# ---> 52 inferred_schema_rows = session_wih_pwd.sql(infer_schema_sql).collect()
#      53 print("\nSchema inference completed. Inferred schema rows:")
#      54 print(inferred_schema_rows)
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/telemetry.py:156, in df_collect_api_telemetry.<locals>.wrap(*args, **kwargs)
#     153 @functools.wraps(func)
#     154 def wrap(*args, **kwargs):
#     155     with args[0]._session.query_history() as query_history:
# --> 156         result = func(*args, **kwargs)
#     157     plan = args[0]._select_statement or args[0]._plan
#     158     api_calls = [
#     159         *plan.api_calls,
#     160         {TelemetryField.NAME.value: f"DataFrame.{func.__name__}"},
#     161     ]
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/dataframe.py:603, in DataFrame.collect(self, statement_params, block, log_on_exception, case_sensitive)
#     588 """Executes the query representing this DataFrame and returns the result as a
#     589 list of :class:`Row` objects.
#     590
#    (...)
#     600     :meth:`collect_nowait()`
#     601 """
#     602 with open_telemetry_context_manager(self.collect, self):
# --> 603     return self._internal_collect_with_tag_no_telemetry(
#     604         statement_params=statement_params,
#     605         block=block,
#     606         log_on_exception=log_on_exception,
#     607         case_sensitive=case_sensitive,
#     608     )
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/dataframe.py:651, in DataFrame._internal_collect_with_tag_no_telemetry(self, statement_params, block, data_type, log_on_exception, case_sensitive)
#     639 def _internal_collect_with_tag_no_telemetry(
#     640     self,
#     641     *,
#    (...)
#     649     # we should always call this method instead of collect(), to make sure the
#     650     # query tag is set properly.
# --> 651     return self._session._conn.execute(
#     652         self._plan,
#     653         block=block,
#     654         data_type=data_type,
#     655         _statement_params=create_or_update_statement_params_with_query_tag(
#     656             statement_params or self._statement_params,
#     657             self._session.query_tag,
#     658             SKIP_LEVELS_THREE,
#     659         ),
#     660         log_on_exception=log_on_exception,
#     661         case_sensitive=case_sensitive,
#     662     )
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/server_connection.py:526, in ServerConnection.execute(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     516 if (
#     517     is_in_stored_procedure()
#     518     and not block
#    (...)
#     521     )
#     522 ):  # pragma: no cover
#     523     raise NotImplementedError(
#     524         "Async query is not supported in stored procedure yet"
#     525     )
# --> 526 result_set, result_meta = self.get_result_set(
#     527     plan,
#     528     to_pandas,
#     529     to_iter,
#     530     **kwargs,
#     531     block=block,
#     532     data_type=data_type,
#     533     log_on_exception=log_on_exception,
#     534     case_sensitive=case_sensitive,
#     535 )
#     536 if not block:
#     537     return result_set
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:207, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     203 else:
#     204     ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     205         e
#     206     )
# --> 207     raise ne.with_traceback(tb) from None
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:138, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     136 def wrap(*args, **kwargs):
#     137     try:
# --> 138         return func(*args, **kwargs)
#     139     except snowflake.connector.errors.ProgrammingError as e:
#     140         query = getattr(e, "query", None)
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/server_connection.py:633, in ServerConnection.get_result_set(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, ignore_results, **kwargs)
#     631 for holder, id_ in placeholders.items():
#     632     final_query = final_query.replace(holder, id_)
# --> 633 result = self.run_query(
#     634     final_query,
#     635     to_pandas,
#     636     to_iter and (i == len(main_queries) - 1),
#     637     is_ddl_on_temp_object=query.is_ddl_on_temp_object,
#     638     block=not is_last,
#     639     data_type=data_type,
#     640     async_job_plan=plan,
#     641     log_on_exception=log_on_exception,
#     642     case_sensitive=case_sensitive,
#     643     params=query.params,
#     644     ignore_results=ignore_results,
#     645     **kwargs,
#     646 )
#     647 placeholders[query.query_id_place_holder] = (
#     648     result["sfqid"] if not is_last else result.query_id
#     649 )
#     650 result_meta = get_new_description(self._cursor)
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/server_connection.py:125, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     121     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     122         ex.cause
#     123     )
#     124 except Exception as ex:
# --> 125     raise ex
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/server_connection.py:119, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     117     raise SnowparkClientExceptionMessages.SERVER_SESSION_HAS_BEEN_CLOSED()
#     118 try:
# --> 119     return func(*args, **kwargs)
#     120 except ReauthenticationRequest as ex:
#     121     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     122         ex.cause
#     123     )
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/server_connection.py:433, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, ignore_results, **kwargs)
#     431         query_id_log = f" [queryID: {ex.sfqid}]" if hasattr(ex, "sfqid") else ""
#     432         logger.error(f"Failed to execute query{query_id_log} {query}\n{ex}")
# --> 433     raise ex
#     435 # fetch_pandas_all/batches() only works for SELECT statements
#     436 # We call fetchall() if fetch_pandas_all/batches() fails,
#     437 # because when the query plan has multiple queries, it will
#     438 # have non-select statements, and it shouldn't fail if the user
#     439 # calls to_pandas() to execute the query.
#     440 if block:
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/server_connection.py:418, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, ignore_results, **kwargs)
#     416     kwargs["_statement_params"]["SNOWPARK_SKIP_TXN_COMMIT_IN_DDL"] = True
#     417 if block:
# --> 418     results_cursor = self.execute_and_notify_query_listener(
#     419         query, params=params, **kwargs
#     420     )
#     421     logger.debug(f"Execute query [queryID: {results_cursor.sfqid}] {query}")
#     422 else:
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/snowpark/_internal/server_connection.py:369, in ServerConnection.execute_and_notify_query_listener(self, query, **kwargs)
#     366 def execute_and_notify_query_listener(
#     367     self, query: str, **kwargs: Any
#     368 ) -> SnowflakeCursor:
# --> 369     results_cursor = self._cursor.execute(query, **kwargs)
#     370     self.notify_query_listeners(
#     371         QueryRecord(results_cursor.sfqid, results_cursor.query)
#     372     )
#     373     return results_cursor
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/cursor.py:1087, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _dataframe_ast)
#    1083     is_integrity_error = (
#    1084         code == "100072"
#    1085     )  # NULL result in a non-nullable column
#    1086     error_class = IntegrityError if is_integrity_error else ProgrammingError
# -> 1087     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#    1088 return self
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/errors.py:284, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     261 @staticmethod
#     262 def errorhandler_wrapper(
#     263     connection: SnowflakeConnection | None,
#    (...)
#     266     error_value: dict[str, Any],
#     267 ) -> None:
#     268     """Error handler wrapper that calls the errorhandler method.
#     269
#     270     Args:
#    (...)
#     281         exception to the first handler in that order.
#     282     """
# --> 284     handed_over = Error.hand_to_other_handler(
#     285         connection,
#     286         cursor,
#     287         error_class,
#     288         error_value,
#     289     )
#     290     if not handed_over:
#     291         raise Error.errorhandler_make_exception(
#     292             error_class,
#     293             error_value,
#     294         )
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/errors.py:339, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     337 if cursor is not None:
#     338     cursor.messages.append((error_class, error_value))
# --> 339     cursor.errorhandler(connection, cursor, error_class, error_value)
#     340     return True
#     341 elif connection is not None:
#
# File /workspaces/MediAssist-Healthcare-Data-Solutions/.myenv/lib/python3.8/site-packages/snowflake/connector/errors.py:215, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     213 errno = error_value.get("errno")
#     214 done_format_msg = error_value.get("done_format_msg")
# --> 215 raise error_class(
#     216     msg=error_value.get("msg"),
#     217     errno=None if errno is None else int(errno),
#     218     sqlstate=error_value.get("sqlstate"),
#     219     sfqid=error_value.get("sfqid"),
#     220     query=error_value.get("query"),
#     221     done_format_msg=(
#     222         None if done_format_msg is None else bool(done_format_msg)
#     223     ),
#     224     connection=connection,
#     225     cursor=cursor,
#     226 )
#
# SnowparkSQLException: (1304): 01b82d07-0004-20d3-0000-13e7001a3e6e: 100332 (22000): Error with CSV header: header defined 27 columns while data contains 10 columns.
#
#   File 'pharmacy.csv.gz'
#   Row 0 starts at line 0, column

# %% [markdown]
# DOSES_PER_24_HRS

# %%
import os
from datetime import datetime

# %%
def create_file_format(session):
    print("Creating file format for DDL...")

    # File format for DDL and loading the CSVs
    session.sql("""
        CREATE OR REPLACE FILE FORMAT file_format_ddl
        TYPE = 'CSV'
        COMPRESSION = 'auto'                   -- Specify GZIP compression for .gz files
        FIELD_DELIMITER = ','                   -- Specify the field delimiter
        PARSE_HEADER = TRUE                    -- Parse the header row for column names
        FIELD_OPTIONALLY_ENCLOSED_BY = '\042'  -- Handle fields enclosed in double quotes
        ESCAPE_UNENCLOSED_FIELD = NONE 
        TRIM_SPACE = TRUE 
        ERROR_ON_COLUMN_COUNT_MISMATCH = FALSE;
    """).collect()

    print("File format 'file_format_ddl' created successfully.")
    print("===========")

    # File format for loading CSV
    session.sql("""
        CREATE OR REPLACE FILE FORMAT file_format_load
        TYPE = 'CSV'
        COMPRESSION = 'auto'                   -- Specify GZIP compression for .gz files
        FIELD_DELIMITER = ','                   -- Specify the field delimiter
        RECORD_DELIMITER = '\n' 
        SKIP_HEADER = 1                        -- Parse the header row for column names
        FIELD_OPTIONALLY_ENCLOSED_BY = '"'     -- Handle quoted fields
        ESCAPE_UNENCLOSED_FIELD = NONE;
    """).collect()

    print("File format 'file_format_load' created successfully.")
    print("===========")

    # Generic file format with GZIP compression and quoted fields handling
    session.sql("""
        CREATE OR REPLACE FILE FORMAT file_format_generic
        TYPE = 'CSV'
        COMPRESSION = 'GZIP'                   -- Specify GZIP compression for .gz files
        FIELD_DELIMITER = ','                   -- Specify the field delimiter
        PARSE_HEADER = TRUE                    -- Parse the header row for column names
        FIELD_OPTIONALLY_ENCLOSED_BY = '"'     -- Handle quoted fields
        ESCAPE_UNENCLOSED_FIELD = NONE;
    """).collect()

    print("File format 'file_format_generic' created successfully.")
    print("===========")

# %%
create_file_format(session_wih_pwd)
# Out:
# Creating file format for DDL...
# File format 'file_format_ddl' created successfully.
# ===========
# File format 'file_format_load' created successfully.
# ===========
# File format 'file_format_generic' created successfully.
# ===========

# %%
# Iterating over the staged files
for row in stg_files:
    print("======================================================\n")
    print(row)
    row_value = row.as_dict()
    print(row_value)

    # Get the file path and name
    stg_file_path_value = row_value.get('name')
    print(stg_file_path_value)

    file_path, file_name = os.path.split(stg_file_path_value)
    print(file_path)
    print(file_name)

    # Define the storage location in Snowflake stage
    stg_location = "@"+file_path
    print(stg_location)

    # Only process 'pharmacy_two.csv.gz' file
    if file_name != 'pharmacy_two.csv.gz':
        continue

    # Prepare SQL to infer the schema of the CSV
    infer_schema_sql = f"""
        SELECT * 
        FROM TABLE(
            INFER_SCHEMA(
            LOCATION=>'{stg_location}/',
            files => '{file_name}',
            FILE_FORMAT => 'file_format_generic'
        )    
    )
    """
    print(f"\n=========== INFER SCHEMA SQL =============")
    print(f" {file_name}")
    print(f"\n=========== INFER SCHEMA SQL =============")
    print(infer_schema_sql)

    # Execute the schema inference
    inferred_schema_rows = session_wih_pwd.sql(infer_schema_sql).collect()
    print("\n============== print(inferred_schema_rows) ================== \n")
    print(inferred_schema_rows)

    # Extract column names and types
    col_name_lst = []
    col_data_type_lst = []

    for row in inferred_schema_rows:
        row_value = row.as_dict()
        print(row_value)
        column_name = row_value.get('COLUMN_NAME')
        column_type = row_value.get('TYPE')

        col_name_lst.append(column_name)
        col_data_type_lst.append(column_type)

    # Generate the DDL statement for creating the table
    table_name = file_name.split('.')[0] + "_raw"
    create_ddl_stmt = generate_ddl_statement(col_name_lst, col_data_type_lst, table_name.upper())
    print("=================== DDL STATEMENT =====================")
    print(create_ddl_stmt)

    # Generate the copy statement for loading data
    copy_stmt = generate_copy_statement(table_name, 'my_internal_stage', file_name, 'file_format_load')
    print("=================== copy_stmt =====================")
    print(copy_stmt)

    # Write the SQL statements to a file
    sql_file_path = table_name + ".sql"
    print("=========================== sql_file_path =============================")
    print(f"{sql_file_path}")
    with open(sql_file_path, "w") as sql_file:
        sql_file.write("---- Following statement is creating table\n\n")
        sql_file.write(create_ddl_stmt)
        sql_file.write("\n-- Following statement is executing copy command")
        sql_file.write(copy_stmt)

    # Execute the DDL and copy commands
    session_wih_pwd.sql(create_ddl_stmt).collect()
    session_wih_pwd.sql(copy_stmt).collect()

# Track the end time of the operations
utc_end_time = datetime.utcnow()

# Print the total time taken for the operations
print(utc_end_time - utc_start_time)
# Out:
# ======================================================
#
# Row(name='my_internal_stage/admissions.csv.gz', size=19652448, md5='e030d760b3e15ce1c6aa9e8e8637ebcd', last_modified='Wed, 9 Oct 2024 06:45:27 GMT')
# {'name': 'my_internal_stage/admissions.csv.gz', 'size': 19652448, 'md5': 'e030d760b3e15ce1c6aa9e8e8637ebcd', 'last_modified': 'Wed, 9 Oct 2024 06:45:27 GMT'}
# my_internal_stage/admissions.csv.gz
# my_internal_stage
# admissions.csv.gz
# @my_internal_stage
# ======================================================
#
# Row(name='my_internal_stage/d_icd_diagnoses.csv.gz', size=849392, md5='d77fe5f8249b16ed3692e52bd781dc06', last_modified='Wed, 9 Oct 2024 06:45:17 GMT')
# {'name': 'my_internal_stage/d_icd_diagnoses.csv.gz', 'size': 849392, 'md5': 'd77fe5f8249b16ed3692e52bd781dc06', 'last_modified': 'Wed, 9 Oct 2024 06:45:17 GMT'}
# my_internal_stage/d_icd_diagnoses.csv.gz
# my_internal_stage
# d_icd_diagnoses.csv.gz
# @my_internal_stage
# ======================================================
#
# Row(name='my_internal_stage/d_icd_procedures.csv.gz', size=549936, md5='d4a9b85d7ee6a75d32f6e1d61ac173cf', last_modified='Wed, 9 Oct 2024 06:44:37 GMT')
# {'name': 'my_internal_stage/d_icd_procedures.csv.gz', 'size': 549936, 'md5': 'd4a9b85d7ee6a75d32f6e1d61ac173cf', 'last_modified': 'Wed, 9 Oct 2024 06:44:37 GMT'}
# my_internal_stage/d_icd_procedures.csv.gz
# my_internal_stage
# d_icd_procedures.csv.gz
# @my_internal_stage
# ======================================================
#
# Row(name='my_internal_stage/discharge_two.csv.gz', size=1138715888, md5='b85ea55aef83c331f7c821e2e425f0de-136', last_modified='Sat, 12 Oct 2024 04:05:15 GMT')
# {'name': 'my_internal_stage/discharge_two.csv.gz', 'size': 1138715888, 'md5': 'b85ea55aef83c331f7c821e2e425f0de-136', 'last_modified': 'Sat, 12 Oct 2024 04:05:15 GMT'}
# my_internal_stage/discharge_two.csv.gz
# my_internal_stage
# discharge_two.csv.gz
# @my_internal_stage
# ======================================================
#
# Row(name='my_internal_stage/drgcodes.csv.gz', size=9509520, md5='89a92ba0a394557ceaa16cfcf7c93bce', last_modified='Wed, 9 Oct 2024 06:45:16 GMT')
# {'name': 'my_internal_stage/drgcodes.csv.gz', 'size': 9509520, 'md5': '89a92ba0a394557ceaa16cfcf7c93bce', 'last_modified': 'Wed, 9 Oct 2024 06:45:16 GMT'}
# my_internal_stage/drgcodes.csv.gz
# my_internal_stage
# drgcodes.csv.gz
# @my_internal_stage
# ======================================================
#
# Row(name='my_internal_stage/pharmacy.csv.gz', size=28197696, md5='880636d6f06cccdcb30a3b541320f35b', last_modified='Tue, 5 Nov 2024 20:32:14 GMT')
# {'name': 'my_internal_stage/pharmacy.csv.gz', 'size': 28197696, 'md5': '880636d6f06cccdcb30a3b541320f35b', 'last_modified': 'Tue, 5 Nov 2024 20:32:14 GMT'}
# my_internal_stage/pharmacy.csv.gz
# my_internal_stage
# pharmacy.csv.gz
# @my_internal_stage
# 0:07:39.253234
